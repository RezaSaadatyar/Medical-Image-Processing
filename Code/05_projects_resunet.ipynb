# %% [markdown]
# ***Welcome to Medical image processing in Python***<br/>
#
# Presented by: Reza Saadatyar (2024-2025) <br/>
# E-mail: Reza.Saadatyar@outlook.com<br/>
# **[GitHub](https://github.com/RezaSaadatyar/Deep-Learning-in-python)**

# %%
# This code is specifically designed for Google Colab environment
# It clones a GitHub repository containing medical image processing code and sets up the environment

# Clone the Medical-Image-Processing repository from GitHub using git command
# In Colab, this will clone into the /content directory by default
# !git clone https://github.com/RezaSaadatyar/Medical-Image-Processing

# List contents of the cloned repository directory to verify successful cloning
# Colab's !ls command shows files in the current directory
# !ls /content/Medical-Image-Processing

# Change working directory to the Code subdirectory of the cloned repository
# %cd is a Colab magic command to change directories
# %cd /content/Medical-Image-Processing/Code

# Import Python's system module for path manipulation
import sys

# Add the Functions subdirectory to Python's system path for module imports
# This allows importing custom modules from the cloned repository
sys.path.append('/content/Medical-Image-Processing/Code/Functions')

# Install the colorama package using pip for colored terminal text
# Colab's !pip install installs packages in the current runtime environment
! pip install colorama
# Out:
# Cloning into 'Medical-Image-Processing'...
# remote: Enumerating objects: 8933, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 8933 (delta 6), reused 12 (delta 3), pack-reused 8914 (from 2)
# Receiving objects: 100% (8933/8933), 984.78 MiB | 26.42 MiB/s, done.
# Resolving deltas: 100% (3234/3234), done.
# Updating files: 100% (7742/7742), done.
# Code  Data  Image  LICENSE  README.md  Results
# /content/Medical-Image-Processing/Code
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# <font color='#FF000e' size="4.8" face="Arial"><b>Importing libraries</b></font>

# %%
import pprint
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple, Union

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping

from Functions.image_processor import ImageProcessor
from Functions.filepath_extractor import FilePathExtractor
from Functions.prepare_dataset import prepare_dataset
from Functions.resunet_model import resunet_model
from Functions.segmentation_metrics import segmentation_metrics
from Functions.show_image_training_progress import ShowImageTrainingProgress
from Functions.plot_training_history import plot_training_history
from Functions.plot_evaluation_results import plot_evaluation_results
from Functions.evaluate_segmentation_predictions import evaluate_segmentation_predictions
from Functions.display_predictions import display_predictions

# %% [markdown]
# <font color=#eff30b size="4.5" face="Arial"><b>1️⃣ Project 1: Brain Tumor Image Segmentation</b></font>

# %%
# ======================================= 1. Importing the dataset =============================================
# ------------------------------------------------ Images ------------------------------------------------------
img_format_type = "png"   # png, jpg, jpeg, tiff, bmp, tif, etc.
# image_path = "/content/Medical-Image-Processing/Data/Brain tumor/images"
image_path = "D:/Medical-Image-Processing/Data/Brain tumor/images/"

# Create an instance of DirectoryReader with the directory path and file format
obj_inputs = FilePathExtractor(directory_path=image_path, format_type=img_format_type)
img_filesname = obj_inputs.filesname         # List of filesname in the directory

# ------------------------------------------------ Masks -------------------------------------------------------
mask_format_type = "png"  # png, jpg, jpeg, tiff, bmp, tif, etc.

# mask_path = "/content/Medical-Image-Processing/Data/Brain tumor/masks"
mask_path = "D:/Medical-Image-Processing/Data/Brain tumor/masks/"

# Create an instance of DirectoryReader with the directory path and file format
obj_masks = FilePathExtractor(directory_path=mask_path, format_type=mask_format_type)
mask_filesname = obj_masks.filesname      # List of filesname in the directory

# -------------------------------------------- Check of the Images ---------------------------------------------
# Compare the base filenames (without extensions) of input files and mask files
# This line checks if the list of base filenames for input files matches the list of base filenames for mask files
[i.split(img_format_type)[0] for i in img_filesname] == [i.split(mask_format_type)[0] for i in mask_filesname]

# ============================ 2.Convert the images into array & masks to binary ===============================
# Create an instance of the `ImageProcessor` class
obj = ImageProcessor()

# Use the `read_images` method of the `ImageProcessor` object to load images from the directory
# The images are expected to be in "png or tif" format, and they are converted into a NumPy array
images = obj.read_images(image_path=image_path, format_type=img_format_type, resize=(256, 256), normalize=True)

# Use the `mask_read` method of the `ImageProcessor` object to load mask images from the directory
# The masks are expected to be in "TIF" format, and they are converted into a NumPy array
masks = obj.read_masks(mask_path=mask_path, format_type=mask_format_type, resize=(256, 256), normalize=True, num_classes=2)

ind = 20 # Set the index of the image and mask to display
plt.figure(figsize=(5, 3))
plt.subplot(121); plt.imshow(images[ind], cmap='gray'); plt.title(f'Image {ind}', fontsize=10)
plt.subplot(122); plt.imshow(masks[ind], cmap='gray'); plt.title(f'Mask {ind}', fontsize=10)
plt.tight_layout() # Adjust the layout to prevent overlap between subplots

# ===================== Prepare TensorFlow datasets for training, validation, and testing ======================
batch_size = 4

# Assuming data_resize and masks_resize are your input data and masks
train_dataset, valid_dataset, test_dataset = prepare_dataset(
    data=images,
    labels=masks,
    train_size=0.6,
    valid_size=0.25,
    batch_size=batch_size,
    shuffle_train=True,
    shuffle_buffer_size=1000,
)
train_dataset, valid_dataset, test_dataset = train_dataset.take(150), valid_dataset.take(50), test_dataset.take(20)
# ================================================= U-Net model ================================================
# Convert any tf.placeholder usage to tf.compat.v1.placeholder
tf.placeholder = tf.compat.v1.placeholder if hasattr(tf, 'placeholder') else None
img_height, img_width, img_channels = list(train_dataset.element_spec[0].shape[1:])
model = resunet_model(img_height,
                   img_width,
                   img_channels,
                   strides=1,
                   base_filters=16,
                   kernel_size=(3, 3),
                   shortcut_kernel_size=(1, 1),
                   n_class=1,
                  )
# model.summary()

# ======================================= Segmentation Metrics & compile =======================================
metrics = segmentation_metrics(alpha=0.1)
adam = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False)
# Compile the model with custom loss and metrics
model.compile(
    optimizer=adam,               # Or 'adam', 'rmsprop'
    loss='binary_crossentropy', # Or binary_crossentropy, 'sparse_categorical_crossentropy', metrics['dice_coef_loss'], 'iou_coef_loss', 'combined_loss'
    metrics=[
        'accuracy',
        metrics['dice_coef'],
        metrics['iou'],
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision'),
        ],
    run_eagerly=False,  # Set run_eagerly=False for better performance
    )

 # ================================================ Callbacks ===================================================
# csv_path = os.path.join("files", "log.csv")
csv_path = 'training_log_BrainTumor_resunet.csv'  # File to log training metrics for UNet model
model_checkpoint_path = 'BrainTumor_resunet_model.keras'  # File to save the best UNet model

callbacks = [
    CSVLogger(csv_path),  # Logs metrics to a CSV file
    ModelCheckpoint(
        filepath=model_checkpoint_path,
        monitor='val_loss',   # Monitor validation loss
        verbose=1,            # Print when saving
        save_best_only=True   # Save only when val_loss improves
    ),
    ReduceLROnPlateau(
        monitor='val_loss',   # Monitor validation loss
        factor=0.1,           # Reduce learning rate by 10x
        patience=10,          # Wait 5 epochs without improvement
        min_lr=1e-6,          # Minimum learning rate
        verbose=1             # Print when reducing LR
    ),
    EarlyStopping(
        monitor='val_loss',         # Monitor validation loss
        patience=10,                # Stop after patience epochs without improvement
        restore_best_weights=True   # Restore best weights (changed to True for better results)
    ),
    ShowImageTrainingProgress(train_dataset, sample_idx=0, figsize=(8, 3.5)),  # Show the first sample in the batch
]

# ============================================ Training the model ==============================================
# Hyperparameters
num_epochs = 50
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    callbacks=callbacks,
    validation_data=valid_dataset,
    shuffle=False,
    verbose=1,
)

# Evaluate on test set
results = model.evaluate(test_dataset, return_dict=True, verbose=1)

# ============================================ Test the model ==================================================
predictions = model.predict(test_dataset, verbose=0)
evaluate_segmentation_predictions(test_dataset=test_dataset, predictions=predictions, num_sample=3)

# ================================================ Results =====================================================
# Plot the history
plot_training_history(history, figsize=(8, 4))
plot_evaluation_results(results, figsize=(4, 4))

# Extract a small batch of data from test_dataset for visualization
for batch in test_dataset.take(1):
    test_images, test_masks = batch
    break

# Convert to numpy arrays for easier manipulation
test_images = test_images.numpy()
test_masks = test_masks.numpy()
display_predictions(test_images, test_masks, predictions, indx=0, figsize=(6, 4))
# Out:
# Image shape: (3064, 256, 256, 1)
# masks.shape = (3064, 256, 256, 1)
# Total number of classes in masks: 2
# Class counts in masks:
#   Class 0.00: 197408980
#   Class 1.00: 3393324
# Training set:   (1838, 256, 256, 1) features, (1838, 256, 256, 1) labels
# Validation set: (766, 256, 256, 1) features, (766, 256, 256, 1) labels
# Test set:       (460, 256, 256, 1) features, (460, 256, 256, 1) labels
#
# Batch size:     4
# Training shuffle: enabled
#
# (TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None))
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9587 - dice_coef: 0.1160 - iou: 0.0635 - loss: 0.1150 - precision: 0.1043 - recall: 0.0795
# Epoch 1: val_loss improved from inf to 0.07317, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 67s 128ms/step - accuracy: 0.9588 - dice_coef: 0.1163 - iou: 0.0637 - loss: 0.1147 - precision: 0.1051 - recall: 0.0796 - val_accuracy: 0.9832 - val_dice_coef: 0.1065 - val_iou: 0.0573 - val_loss: 0.0732 - val_precision: 0.3278 - val_recall: 0.0297 - learning_rate: 0.0010
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9858 - dice_coef: 0.2686 - iou: 0.1607 - loss: 0.0484 - precision: 0.6831 - recall: 0.2326
# Epoch 2: val_loss did not improve from 0.07317
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 102ms/step - accuracy: 0.9858 - dice_coef: 0.2685 - iou: 0.1606 - loss: 0.0484 - precision: 0.6831 - recall: 0.2325 - val_accuracy: 0.9656 - val_dice_coef: 0.1073 - val_iou: 0.0582 - val_loss: 0.2240 - val_precision: 0.1434 - val_recall: 0.2232 - learning_rate: 0.0010
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9867 - dice_coef: 0.2914 - iou: 0.1768 - loss: 0.0441 - precision: 0.7045 - recall: 0.2602
# Epoch 3: val_loss did not improve from 0.07317
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - accuracy: 0.9867 - dice_coef: 0.2915 - iou: 0.1769 - loss: 0.0441 - precision: 0.7045 - recall: 0.2604 - val_accuracy: 0.9230 - val_dice_coef: 0.1840 - val_iou: 0.1036 - val_loss: 0.1753 - val_precision: 0.1393 - val_recall: 0.7173 - learning_rate: 0.0010
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9863 - dice_coef: 0.3408 - iou: 0.2114 - loss: 0.0424 - precision: 0.7101 - recall: 0.3143
# Epoch 4: val_loss improved from 0.07317 to 0.07238, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9863 - dice_coef: 0.3410 - iou: 0.2115 - loss: 0.0424 - precision: 0.7102 - recall: 0.3144 - val_accuracy: 0.9841 - val_dice_coef: 0.1294 - val_iou: 0.0717 - val_loss: 0.0724 - val_precision: 0.6506 - val_recall: 0.0574 - learning_rate: 0.0010
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9859 - dice_coef: 0.3572 - iou: 0.2234 - loss: 0.0429 - precision: 0.7176 - recall: 0.3192
# Epoch 5: val_loss did not improve from 0.07238
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - accuracy: 0.9859 - dice_coef: 0.3572 - iou: 0.2235 - loss: 0.0429 - precision: 0.7175 - recall: 0.3193 - val_accuracy: 0.9736 - val_dice_coef: 0.2049 - val_iou: 0.1166 - val_loss: 0.0747 - val_precision: 0.2800 - val_recall: 0.3912 - learning_rate: 0.0010
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9875 - dice_coef: 0.4195 - iou: 0.2734 - loss: 0.0367 - precision: 0.7409 - recall: 0.3976
# Epoch 6: val_loss improved from 0.07238 to 0.04199, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - accuracy: 0.9875 - dice_coef: 0.4195 - iou: 0.2734 - loss: 0.0367 - precision: 0.7409 - recall: 0.3976 - val_accuracy: 0.9862 - val_dice_coef: 0.4382 - val_iou: 0.2939 - val_loss: 0.0420 - val_precision: 0.6072 - val_recall: 0.4425 - learning_rate: 0.0010
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9874 - dice_coef: 0.4084 - iou: 0.2621 - loss: 0.0360 - precision: 0.7172 - recall: 0.3987
# Epoch 7: val_loss improved from 0.04199 to 0.03699, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 111ms/step - accuracy: 0.9874 - dice_coef: 0.4084 - iou: 0.2621 - loss: 0.0360 - precision: 0.7172 - recall: 0.3987 - val_accuracy: 0.9884 - val_dice_coef: 0.4303 - val_iou: 0.2851 - val_loss: 0.0370 - val_precision: 0.8396 - val_recall: 0.3554 - learning_rate: 0.0010
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9880 - dice_coef: 0.4518 - iou: 0.2975 - loss: 0.0338 - precision: 0.7696 - recall: 0.4404
# Epoch 8: val_loss improved from 0.03699 to 0.03385, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9880 - dice_coef: 0.4518 - iou: 0.2976 - loss: 0.0338 - precision: 0.7695 - recall: 0.4406 - val_accuracy: 0.9882 - val_dice_coef: 0.3880 - val_iou: 0.2506 - val_loss: 0.0339 - val_precision: 0.8869 - val_recall: 0.3203 - learning_rate: 0.0010
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9892 - dice_coef: 0.4782 - iou: 0.3236 - loss: 0.0293 - precision: 0.7414 - recall: 0.4825
# Epoch 9: val_loss did not improve from 0.03385
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9892 - dice_coef: 0.4782 - iou: 0.3237 - loss: 0.0293 - precision: 0.7414 - recall: 0.4826 - val_accuracy: 0.9871 - val_dice_coef: 0.4081 - val_iou: 0.2647 - val_loss: 0.0366 - val_precision: 0.6250 - val_recall: 0.5309 - learning_rate: 0.0010
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9901 - dice_coef: 0.4834 - iou: 0.3296 - loss: 0.0287 - precision: 0.7741 - recall: 0.5251
# Epoch 10: val_loss did not improve from 0.03385
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9901 - dice_coef: 0.4835 - iou: 0.3296 - loss: 0.0287 - precision: 0.7740 - recall: 0.5250 - val_accuracy: 0.9702 - val_dice_coef: 0.2652 - val_iou: 0.1571 - val_loss: 0.0730 - val_precision: 0.2911 - val_recall: 0.5768 - learning_rate: 0.0010
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9892 - dice_coef: 0.4970 - iou: 0.3404 - loss: 0.0292 - precision: 0.7274 - recall: 0.5312
# Epoch 11: val_loss did not improve from 0.03385
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 110ms/step - accuracy: 0.9892 - dice_coef: 0.4971 - iou: 0.3405 - loss: 0.0292 - precision: 0.7276 - recall: 0.5312 - val_accuracy: 0.9822 - val_dice_coef: 0.3526 - val_iou: 0.2207 - val_loss: 0.0506 - val_precision: 0.4645 - val_recall: 0.5759 - learning_rate: 0.0010
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9901 - dice_coef: 0.5265 - iou: 0.3658 - loss: 0.0276 - precision: 0.7572 - recall: 0.5620
# Epoch 12: val_loss did not improve from 0.03385
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9901 - dice_coef: 0.5266 - iou: 0.3659 - loss: 0.0276 - precision: 0.7573 - recall: 0.5621 - val_accuracy: 0.9864 - val_dice_coef: 0.4116 - val_iou: 0.2681 - val_loss: 0.0374 - val_precision: 0.5922 - val_recall: 0.5300 - learning_rate: 0.0010
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9911 - dice_coef: 0.5696 - iou: 0.4055 - loss: 0.0246 - precision: 0.7746 - recall: 0.6140
# Epoch 13: val_loss improved from 0.03385 to 0.03288, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.9911 - dice_coef: 0.5694 - iou: 0.4053 - loss: 0.0246 - precision: 0.7746 - recall: 0.6138 - val_accuracy: 0.9885 - val_dice_coef: 0.4725 - val_iou: 0.3254 - val_loss: 0.0329 - val_precision: 0.7200 - val_recall: 0.4818 - learning_rate: 0.0010
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9905 - dice_coef: 0.5703 - iou: 0.4086 - loss: 0.0253 - precision: 0.7670 - recall: 0.6153
# Epoch 14: val_loss did not improve from 0.03288
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9905 - dice_coef: 0.5703 - iou: 0.4086 - loss: 0.0253 - precision: 0.7672 - recall: 0.6153 - val_accuracy: 0.9870 - val_dice_coef: 0.4408 - val_iou: 0.2942 - val_loss: 0.0364 - val_precision: 0.6184 - val_recall: 0.5275 - learning_rate: 0.0010
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9904 - dice_coef: 0.5575 - iou: 0.3951 - loss: 0.0273 - precision: 0.7701 - recall: 0.5977
# Epoch 15: val_loss did not improve from 0.03288
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9904 - dice_coef: 0.5575 - iou: 0.3951 - loss: 0.0273 - precision: 0.7701 - recall: 0.5977 - val_accuracy: 0.9856 - val_dice_coef: 0.4093 - val_iou: 0.2691 - val_loss: 0.0380 - val_precision: 0.5608 - val_recall: 0.5421 - learning_rate: 0.0010
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9916 - dice_coef: 0.5961 - iou: 0.4351 - loss: 0.0235 - precision: 0.8070 - recall: 0.6447
# Epoch 16: val_loss did not improve from 0.03288
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9916 - dice_coef: 0.5961 - iou: 0.4351 - loss: 0.0235 - precision: 0.8069 - recall: 0.6447 - val_accuracy: 0.9886 - val_dice_coef: 0.4672 - val_iou: 0.3184 - val_loss: 0.0354 - val_precision: 0.7702 - val_recall: 0.4287 - learning_rate: 0.0010
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9919 - dice_coef: 0.5903 - iou: 0.4309 - loss: 0.0218 - precision: 0.7961 - recall: 0.6454
# Epoch 17: val_loss did not improve from 0.03288
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9919 - dice_coef: 0.5904 - iou: 0.4310 - loss: 0.0218 - precision: 0.7961 - recall: 0.6454 - val_accuracy: 0.9890 - val_dice_coef: 0.5054 - val_iou: 0.3550 - val_loss: 0.0373 - val_precision: 0.7354 - val_recall: 0.5107 - learning_rate: 0.0010
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9921 - dice_coef: 0.6259 - iou: 0.4647 - loss: 0.0214 - precision: 0.8016 - recall: 0.6828
# Epoch 18: val_loss improved from 0.03288 to 0.02910, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.9921 - dice_coef: 0.6260 - iou: 0.4647 - loss: 0.0214 - precision: 0.8017 - recall: 0.6828 - val_accuracy: 0.9882 - val_dice_coef: 0.5698 - val_iou: 0.4115 - val_loss: 0.0291 - val_precision: 0.6199 - val_recall: 0.7229 - learning_rate: 0.0010
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9932 - dice_coef: 0.6756 - iou: 0.5198 - loss: 0.0174 - precision: 0.8179 - recall: 0.7318
# Epoch 19: val_loss improved from 0.02910 to 0.02320, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - accuracy: 0.9932 - dice_coef: 0.6755 - iou: 0.5197 - loss: 0.0174 - precision: 0.8179 - recall: 0.7317 - val_accuracy: 0.9910 - val_dice_coef: 0.6189 - val_iou: 0.4636 - val_loss: 0.0232 - val_precision: 0.7244 - val_recall: 0.7259 - learning_rate: 0.0010
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9932 - dice_coef: 0.6869 - iou: 0.5311 - loss: 0.0177 - precision: 0.8203 - recall: 0.7558
# Epoch 20: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9932 - dice_coef: 0.6867 - iou: 0.5309 - loss: 0.0177 - precision: 0.8204 - recall: 0.7555 - val_accuracy: 0.9908 - val_dice_coef: 0.6078 - val_iou: 0.4515 - val_loss: 0.0253 - val_precision: 0.7309 - val_recall: 0.6940 - learning_rate: 0.0010
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9924 - dice_coef: 0.6595 - iou: 0.5008 - loss: 0.0196 - precision: 0.8092 - recall: 0.7136
# Epoch 21: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9924 - dice_coef: 0.6594 - iou: 0.5007 - loss: 0.0196 - precision: 0.8093 - recall: 0.7136 - val_accuracy: 0.9877 - val_dice_coef: 0.4823 - val_iou: 0.3344 - val_loss: 0.0379 - val_precision: 0.6589 - val_recall: 0.5075 - learning_rate: 0.0010
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9937 - dice_coef: 0.7030 - iou: 0.5484 - loss: 0.0161 - precision: 0.8335 - recall: 0.7666
# Epoch 22: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9937 - dice_coef: 0.7030 - iou: 0.5484 - loss: 0.0161 - precision: 0.8336 - recall: 0.7665 - val_accuracy: 0.9905 - val_dice_coef: 0.5635 - val_iou: 0.4128 - val_loss: 0.0336 - val_precision: 0.8854 - val_recall: 0.4783 - learning_rate: 0.0010
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9944 - dice_coef: 0.7429 - iou: 0.5968 - loss: 0.0150 - precision: 0.8602 - recall: 0.7908
# Epoch 23: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - accuracy: 0.9944 - dice_coef: 0.7429 - iou: 0.5967 - loss: 0.0150 - precision: 0.8602 - recall: 0.7907 - val_accuracy: 0.9915 - val_dice_coef: 0.6250 - val_iou: 0.4695 - val_loss: 0.0266 - val_precision: 0.8382 - val_recall: 0.5965 - learning_rate: 0.0010
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9948 - dice_coef: 0.7471 - iou: 0.6027 - loss: 0.0130 - precision: 0.8513 - recall: 0.8084
# Epoch 24: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9948 - dice_coef: 0.7471 - iou: 0.6026 - loss: 0.0130 - precision: 0.8513 - recall: 0.8084 - val_accuracy: 0.9888 - val_dice_coef: 0.4865 - val_iou: 0.3336 - val_loss: 0.0304 - val_precision: 0.6623 - val_recall: 0.6393 - learning_rate: 0.0010
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9942 - dice_coef: 0.7192 - iou: 0.5696 - loss: 0.0147 - precision: 0.8595 - recall: 0.7684
# Epoch 25: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9942 - dice_coef: 0.7192 - iou: 0.5696 - loss: 0.0147 - precision: 0.8595 - recall: 0.7685 - val_accuracy: 0.9914 - val_dice_coef: 0.6034 - val_iou: 0.4478 - val_loss: 0.0255 - val_precision: 0.8411 - val_recall: 0.5833 - learning_rate: 0.0010
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9947 - dice_coef: 0.7416 - iou: 0.5945 - loss: 0.0138 - precision: 0.8514 - recall: 0.8027
# Epoch 26: val_loss did not improve from 0.02320
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.9947 - dice_coef: 0.7416 - iou: 0.5945 - loss: 0.0138 - precision: 0.8515 - recall: 0.8027 - val_accuracy: 0.9913 - val_dice_coef: 0.6077 - val_iou: 0.4548 - val_loss: 0.0295 - val_precision: 0.8497 - val_recall: 0.5688 - learning_rate: 0.0010
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9949 - dice_coef: 0.7445 - iou: 0.6027 - loss: 0.0135 - precision: 0.8676 - recall: 0.8030
# Epoch 27: val_loss improved from 0.02320 to 0.02271, saving model to BrainTumor_resunet_model.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - accuracy: 0.9949 - dice_coef: 0.7445 - iou: 0.6028 - loss: 0.0135 - precision: 0.8677 - recall: 0.8030 - val_accuracy: 0.9916 - val_dice_coef: 0.6061 - val_iou: 0.4515 - val_loss: 0.0227 - val_precision: 0.8047 - val_recall: 0.6404 - learning_rate: 0.0010
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9952 - dice_coef: 0.7816 - iou: 0.6461 - loss: 0.0121 - precision: 0.8731 - recall: 0.8364
# Epoch 28: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 112ms/step - accuracy: 0.9952 - dice_coef: 0.7816 - iou: 0.6461 - loss: 0.0121 - precision: 0.8731 - recall: 0.8363 - val_accuracy: 0.9920 - val_dice_coef: 0.6388 - val_iou: 0.4868 - val_loss: 0.0230 - val_precision: 0.8142 - val_recall: 0.6626 - learning_rate: 0.0010
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9958 - dice_coef: 0.8072 - iou: 0.6816 - loss: 0.0107 - precision: 0.8921 - recall: 0.8592
# Epoch 29: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 109ms/step - accuracy: 0.9958 - dice_coef: 0.8072 - iou: 0.6815 - loss: 0.0107 - precision: 0.8920 - recall: 0.8591 - val_accuracy: 0.9919 - val_dice_coef: 0.6381 - val_iou: 0.4864 - val_loss: 0.0245 - val_precision: 0.8539 - val_recall: 0.6088 - learning_rate: 0.0010
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9957 - dice_coef: 0.7794 - iou: 0.6439 - loss: 0.0110 - precision: 0.8814 - recall: 0.8224
# Epoch 30: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9957 - dice_coef: 0.7794 - iou: 0.6439 - loss: 0.0110 - precision: 0.8814 - recall: 0.8224 - val_accuracy: 0.9908 - val_dice_coef: 0.6437 - val_iou: 0.4891 - val_loss: 0.0259 - val_precision: 0.7216 - val_recall: 0.7120 - learning_rate: 0.0010
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9954 - dice_coef: 0.7537 - iou: 0.6136 - loss: 0.0119 - precision: 0.8608 - recall: 0.8242
# Epoch 31: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9954 - dice_coef: 0.7539 - iou: 0.6138 - loss: 0.0119 - precision: 0.8609 - recall: 0.8243 - val_accuracy: 0.9914 - val_dice_coef: 0.6326 - val_iou: 0.4797 - val_loss: 0.0235 - val_precision: 0.7497 - val_recall: 0.7143 - learning_rate: 0.0010
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9960 - dice_coef: 0.8156 - iou: 0.6912 - loss: 0.0101 - precision: 0.8823 - recall: 0.8679
# Epoch 32: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 108ms/step - accuracy: 0.9960 - dice_coef: 0.8155 - iou: 0.6911 - loss: 0.0101 - precision: 0.8823 - recall: 0.8677 - val_accuracy: 0.9904 - val_dice_coef: 0.5700 - val_iou: 0.4182 - val_loss: 0.0302 - val_precision: 0.7828 - val_recall: 0.5699 - learning_rate: 0.0010
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9952 - dice_coef: 0.7744 - iou: 0.6364 - loss: 0.0124 - precision: 0.8867 - recall: 0.8169
# Epoch 33: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - accuracy: 0.9952 - dice_coef: 0.7745 - iou: 0.6365 - loss: 0.0124 - precision: 0.8867 - recall: 0.8170 - val_accuracy: 0.9910 - val_dice_coef: 0.6325 - val_iou: 0.4814 - val_loss: 0.0255 - val_precision: 0.7286 - val_recall: 0.7125 - learning_rate: 0.0010
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9963 - dice_coef: 0.8097 - iou: 0.6841 - loss: 0.0096 - precision: 0.9008 - recall: 0.8507
# Epoch 34: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9963 - dice_coef: 0.8096 - iou: 0.6840 - loss: 0.0096 - precision: 0.9008 - recall: 0.8507 - val_accuracy: 0.9914 - val_dice_coef: 0.6299 - val_iou: 0.4799 - val_loss: 0.0260 - val_precision: 0.7803 - val_recall: 0.6607 - learning_rate: 0.0010
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9962 - dice_coef: 0.8174 - iou: 0.6942 - loss: 0.0095 - precision: 0.8943 - recall: 0.8642
# Epoch 35: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - accuracy: 0.9962 - dice_coef: 0.8174 - iou: 0.6942 - loss: 0.0095 - precision: 0.8943 - recall: 0.8641 - val_accuracy: 0.9916 - val_dice_coef: 0.6285 - val_iou: 0.4772 - val_loss: 0.0256 - val_precision: 0.8252 - val_recall: 0.6148 - learning_rate: 0.0010
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9957 - dice_coef: 0.7957 - iou: 0.6643 - loss: 0.0106 - precision: 0.8826 - recall: 0.8419
# Epoch 36: val_loss did not improve from 0.02271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 108ms/step - accuracy: 0.9957 - dice_coef: 0.7956 - iou: 0.6643 - loss: 0.0106 - precision: 0.8826 - recall: 0.8418 - val_accuracy: 0.9918 - val_dice_coef: 0.6306 - val_iou: 0.4760 - val_loss: 0.0241 - val_precision: 0.8147 - val_recall: 0.6431 - learning_rate: 0.0010
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9961 - dice_coef: 0.8191 - iou: 0.6964 - loss: 0.0098 - precision: 0.8835 - recall: 0.8776
# Epoch 37: val_loss did not improve from 0.02271
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 16s 110ms/step - accuracy: 0.9961 - dice_coef: 0.8192 - iou: 0.6965 - loss: 0.0098 - precision: 0.8836 - recall: 0.8776 - val_accuracy: 0.9922 - val_dice_coef: 0.6705 - val_iou: 0.5252 - val_loss: 0.0271 - val_precision: 0.8863 - val_recall: 0.6025 - learning_rate: 0.0010
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9910 - dice_coef: 0.5735 - iou: 0.4235 - loss: 0.0257 - precision: 0.8575 - recall: 0.5768
# Sample 1 Accuracy: 0.979; IoU: 0.628; Dice coef: 0.772; Recall: 0.636; Precision: 0.980
# Sample 2 Accuracy: 0.994; IoU: 0.690; Dice coef: 0.816; Recall: 0.694; Precision: 0.991
# Sample 3 Accuracy: 0.981; IoU: 0.500; Dice coef: 0.667; Recall: 0.523; Precision: 0.919

# %% [markdown]
# <font color= #ff25b2 size="4.5" face="Arial"><b>2️⃣ Project 2: Polyp Image Segmentation</b></font>

# %%
# ======================================= 1. Importing the dataset =============================================
# ------------------------------------------------ Images ------------------------------------------------------
img_format_type = "tif"   # png, jpg, jpeg, tiff, bmp, tif, etc.
# image_path = "/content/Medical-Image-Processing/Data/Polyp/images"
image_path = "D:/Medical-Image-Processing/Data/Polyp/images/"

# Create an instance of DirectoryReader with the directory path and file format
obj_inputs = FilePathExtractor(directory_path=image_path, format_type=img_format_type)
img_filesname = obj_inputs.filesname         # List of filesname in the directory

# ------------------------------------------------ Masks -------------------------------------------------------
mask_format_type = "tif"  # png, jpg, jpeg, tiff, bmp, tif, etc.

# mask_path = "/content/Medical-Image-Processing/Data/Polyp/masks"
mask_path = "D:/Medical-Image-Processing/Data/Polyp/masks/"

# Create an instance of DirectoryReader with the directory path and file format
obj_masks = FilePathExtractor(directory_path=mask_path, format_type=mask_format_type)
mask_filesname = obj_masks.filesname      # List of filesname in the directory

# -------------------------------------------- Check of the Images ---------------------------------------------
# Compare the base filenames (without extensions) of input files and mask files
# This line checks if the list of base filenames for input files matches the list of base filenames for mask files
[i.split(img_format_type)[0] for i in img_filesname] == [i.split(mask_format_type)[0] for i in mask_filesname]

# ============================ 2.Convert the images into array & masks to binary ===============================
# Create an instance of the `ImageProcessor` class
obj = ImageProcessor()

# Use the `read_images` method of the `ImageProcessor` object to load images from the directory
# The images are expected to be in "png or tif" format, and they are converted into a NumPy array
images = obj.read_images(image_path=image_path, format_type=img_format_type, resize=None, normalize=True)

# Use the `mask_read` method of the `ImageProcessor` object to load mask images from the directory
# The masks are expected to be in "TIF" format, and they are converted into a NumPy array
masks = obj.read_masks(mask_path=mask_path, format_type=mask_format_type, resize=None, normalize=True, num_classes=2)

ind = 20 # Set the index of the image and mask to display
plt.figure(figsize=(5, 3))
plt.subplot(121); plt.imshow(images[ind], cmap='gray'); plt.title(f'Image {ind}', fontsize=10)
plt.subplot(122); plt.imshow(masks[ind], cmap='gray'); plt.title(f'Mask {ind}', fontsize=10)
plt.tight_layout() # Adjust the layout to prevent overlap between subplots

# ===================== Prepare TensorFlow datasets for training, validation, and testing ======================
batch_size = 4

# Assuming data_resize and masks_resize are your input data and masks
train_dataset, valid_dataset, test_dataset = prepare_dataset(
    data=images,
    labels=masks,
    train_size=0.6,
    valid_size=0.25,
    batch_size=batch_size,
    shuffle_train=True,
    shuffle_buffer_size=1000,
)

# ================================================= U-Net model ================================================
# Convert any tf.placeholder usage to tf.compat.v1.placeholder
tf.placeholder = tf.compat.v1.placeholder if hasattr(tf, 'placeholder') else None
img_height, img_width, img_channels = list(train_dataset.element_spec[0].shape[1:])
model = resunet_model(img_height,
                   img_width,
                   img_channels,
                   strides=1,
                   base_filters=16,
                   kernel_size=(3, 3),
                   shortcut_kernel_size=(1, 1),
                   n_class=1,
                  )
# model.summary()

# ======================================= Segmentation Metrics & compile =======================================
metrics = segmentation_metrics(alpha=0.1)
adam = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False)
# Compile the model with custom loss and metrics
model.compile(
    optimizer=adam,               # Or 'adam', 'rmsprop'
    loss='binary_crossentropy', # Or binary_crossentropy, 'sparse_categorical_crossentropy', metrics['dice_coef_loss'], 'iou_coef_loss', 'combined_loss'
    metrics=[
        'accuracy',
        metrics['dice_coef'],
        metrics['iou'],
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision'),
        ],
    run_eagerly=False,  # Set run_eagerly=False for better performance
    )

# ================================================ Callbacks ===================================================
# csv_path = os.path.join("files", "log.csv")
csv_path = 'training_log_Polyp_resunet.csv'  # File to log training metrics for UNet model
model_checkpoint_path = 'Polyp_resunet_model.keras'  # File to save the best UNet model

callbacks = [
    CSVLogger(csv_path),  # Logs metrics to a CSV file
    ModelCheckpoint(
        filepath=model_checkpoint_path,
        monitor='val_loss',   # Monitor validation loss
        verbose=1,            # Print when saving
        save_best_only=True   # Save only when val_loss improves
    ),
    ReduceLROnPlateau(
        monitor='val_loss',   # Monitor validation loss
        factor=0.1,           # Reduce learning rate by 10x
        patience=10,          # Wait 5 epochs without improvement
        min_lr=1e-6,          # Minimum learning rate
        verbose=1             # Print when reducing LR
    ),
    EarlyStopping(
        monitor='val_loss',         # Monitor validation loss
        patience=10,                # Stop after patience epochs without improvement
        restore_best_weights=True   # Restore best weights (changed to True for better results)
    ),
    ShowImageTrainingProgress(train_dataset, sample_idx=0, figsize=(8, 3.5)),  # Show the first sample in the batch
]

# ============================================ Training the model ==============================================
# Hyperparameters
num_epochs = 50
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    callbacks=callbacks,
    validation_data=valid_dataset,
    shuffle=False,
    verbose=1,
)

# Evaluate on test set
results = model.evaluate(test_dataset, return_dict=True, verbose=1)

# ============================================ Test the model ==================================================
predictions = model.predict(test_dataset, verbose=0)
evaluate_segmentation_predictions(test_dataset=test_dataset, predictions=predictions, num_sample=3)

# ================================================ Results =====================================================
# Plot the history
plot_training_history(history, figsize=(8, 4))
plot_evaluation_results(results, figsize=(4, 4))

# Extract a small batch of data from test_dataset for visualization
for batch in test_dataset.take(1):
    test_images, test_masks = batch
    break

# Convert to numpy arrays for easier manipulation
test_images = test_images.numpy()
test_masks = test_masks.numpy()
display_predictions(test_images, test_masks, predictions, indx=0, figsize=(6, 4))
# Out:
# Image shape: (612, 288, 384, 3)
# masks.shape = (612, 288, 384, 1)
# Total number of classes in masks: 2
# Class counts in masks:
#   Class 0.00: 61387764
#   Class 1.00: 6294540
# Training set:   (367, 288, 384, 3) features, (367, 288, 384, 1) labels
# Validation set: (153, 288, 384, 3) features, (153, 288, 384, 1) labels
# Test set:       (92, 288, 384, 3) features, (92, 288, 384, 1) labels
#
# Batch size:     4
# Training shuffle: enabled
#
# (TensorSpec(shape=(None, 288, 384, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 288, 384, 1), dtype=tf.float32, name=None))
# Epoch 1/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.8791 - dice_coef: 0.2616 - iou: 0.1553 - loss: 0.3076 - precision: 0.3941 - recall: 0.2393
# Epoch 1: val_loss improved from inf to 0.33622, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 108s 588ms/step - accuracy: 0.8793 - dice_coef: 0.2618 - iou: 0.1555 - loss: 0.3070 - precision: 0.3952 - recall: 0.2393 - val_accuracy: 0.9006 - val_dice_coef: 0.1618 - val_iou: 0.0890 - val_loss: 0.3362 - val_precision: 0.2868 - val_recall: 0.0295 - learning_rate: 0.0010
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9181 - dice_coef: 0.3445 - iou: 0.2117 - loss: 0.2052 - precision: 0.6206 - recall: 0.2958
# Epoch 2: val_loss improved from 0.33622 to 0.31431, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9181 - dice_coef: 0.3444 - iou: 0.2117 - loss: 0.2053 - precision: 0.6206 - recall: 0.2958 - val_accuracy: 0.8740 - val_dice_coef: 0.2433 - val_iou: 0.1409 - val_loss: 0.3143 - val_precision: 0.3103 - val_recall: 0.2644 - learning_rate: 0.0010
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9239 - dice_coef: 0.3872 - iou: 0.2437 - loss: 0.2014 - precision: 0.6443 - recall: 0.3939
# Epoch 3: val_loss improved from 0.31431 to 0.29990, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 179ms/step - accuracy: 0.9239 - dice_coef: 0.3869 - iou: 0.2435 - loss: 0.2015 - precision: 0.6442 - recall: 0.3933 - val_accuracy: 0.8859 - val_dice_coef: 0.2573 - val_iou: 0.1508 - val_loss: 0.2999 - val_precision: 0.3560 - val_recall: 0.2449 - learning_rate: 0.0010
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9235 - dice_coef: 0.4118 - iou: 0.2642 - loss: 0.1952 - precision: 0.6655 - recall: 0.4126
# Epoch 4: val_loss improved from 0.29990 to 0.28372, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9236 - dice_coef: 0.4118 - iou: 0.2642 - loss: 0.1952 - precision: 0.6655 - recall: 0.4125 - val_accuracy: 0.9116 - val_dice_coef: 0.3964 - val_iou: 0.2584 - val_loss: 0.2837 - val_precision: 0.5503 - val_recall: 0.3927 - learning_rate: 0.0010
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9237 - dice_coef: 0.3733 - iou: 0.2345 - loss: 0.1941 - precision: 0.6333 - recall: 0.3620
# Epoch 5: val_loss did not improve from 0.28372
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.9238 - dice_coef: 0.3736 - iou: 0.2347 - loss: 0.1941 - precision: 0.6338 - recall: 0.3622 - val_accuracy: 0.6886 - val_dice_coef: 0.2856 - val_iou: 0.1711 - val_loss: 0.5870 - val_precision: 0.2120 - val_recall: 0.8365 - learning_rate: 0.0010
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9338 - dice_coef: 0.4317 - iou: 0.2793 - loss: 0.1769 - precision: 0.7200 - recall: 0.4379
# Epoch 6: val_loss improved from 0.28372 to 0.18746, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 185ms/step - accuracy: 0.9338 - dice_coef: 0.4318 - iou: 0.2795 - loss: 0.1769 - precision: 0.7200 - recall: 0.4381 - val_accuracy: 0.9309 - val_dice_coef: 0.3977 - val_iou: 0.2532 - val_loss: 0.1875 - val_precision: 0.7420 - val_recall: 0.4204 - learning_rate: 0.0010
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9314 - dice_coef: 0.4566 - iou: 0.3005 - loss: 0.1790 - precision: 0.7641 - recall: 0.4316
# Epoch 7: val_loss did not improve from 0.18746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 177ms/step - accuracy: 0.9315 - dice_coef: 0.4568 - iou: 0.3006 - loss: 0.1788 - precision: 0.7638 - recall: 0.4322 - val_accuracy: 0.9069 - val_dice_coef: 0.0349 - val_iou: 0.0192 - val_loss: 0.8952 - val_precision: 0.9863 - val_recall: 0.0224 - learning_rate: 0.0010
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9357 - dice_coef: 0.4865 - iou: 0.3277 - loss: 0.1684 - precision: 0.7566 - recall: 0.5058
# Epoch 8: val_loss did not improve from 0.18746
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9358 - dice_coef: 0.4865 - iou: 0.3277 - loss: 0.1683 - precision: 0.7565 - recall: 0.5059 - val_accuracy: 0.9297 - val_dice_coef: 0.5027 - val_iou: 0.3450 - val_loss: 0.1908 - val_precision: 0.6269 - val_recall: 0.6464 - learning_rate: 0.0010
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9335 - dice_coef: 0.4999 - iou: 0.3385 - loss: 0.1813 - precision: 0.7443 - recall: 0.5193
# Epoch 9: val_loss improved from 0.18746 to 0.16691, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.9336 - dice_coef: 0.5001 - iou: 0.3387 - loss: 0.1811 - precision: 0.7443 - recall: 0.5196 - val_accuracy: 0.9381 - val_dice_coef: 0.4847 - val_iou: 0.3259 - val_loss: 0.1669 - val_precision: 0.7412 - val_recall: 0.5367 - learning_rate: 0.0010
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9485 - dice_coef: 0.5943 - iou: 0.4274 - loss: 0.1379 - precision: 0.8142 - recall: 0.6324
# Epoch 10: val_loss did not improve from 0.16691
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9484 - dice_coef: 0.5939 - iou: 0.4270 - loss: 0.1380 - precision: 0.8138 - recall: 0.6321 - val_accuracy: 0.9388 - val_dice_coef: 0.4355 - val_iou: 0.2841 - val_loss: 0.1763 - val_precision: 0.8306 - val_recall: 0.4480 - learning_rate: 0.0010
# Epoch 11/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9509 - dice_coef: 0.5473 - iou: 0.3817 - loss: 0.1332 - precision: 0.7790 - recall: 0.6011
# Epoch 11: val_loss did not improve from 0.16691
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 177ms/step - accuracy: 0.9509 - dice_coef: 0.5474 - iou: 0.3818 - loss: 0.1333 - precision: 0.7790 - recall: 0.6012 - val_accuracy: 0.9165 - val_dice_coef: 0.4463 - val_iou: 0.2967 - val_loss: 0.2202 - val_precision: 0.5567 - val_recall: 0.6035 - learning_rate: 0.0010
# Epoch 12/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9483 - dice_coef: 0.5727 - iou: 0.4070 - loss: 0.1383 - precision: 0.8012 - recall: 0.6021
# Epoch 12: val_loss did not improve from 0.16691
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 177ms/step - accuracy: 0.9483 - dice_coef: 0.5728 - iou: 0.4070 - loss: 0.1383 - precision: 0.8010 - recall: 0.6022 - val_accuracy: 0.9398 - val_dice_coef: 0.5530 - val_iou: 0.3924 - val_loss: 0.1671 - val_precision: 0.7193 - val_recall: 0.6030 - learning_rate: 0.0010
# Epoch 13/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9498 - dice_coef: 0.6058 - iou: 0.4410 - loss: 0.1323 - precision: 0.8174 - recall: 0.6414
# Epoch 13: val_loss did not improve from 0.16691
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 177ms/step - accuracy: 0.9498 - dice_coef: 0.6057 - iou: 0.4409 - loss: 0.1323 - precision: 0.8172 - recall: 0.6414 - val_accuracy: 0.9342 - val_dice_coef: 0.5724 - val_iou: 0.4130 - val_loss: 0.1669 - val_precision: 0.6298 - val_recall: 0.7485 - learning_rate: 0.0010
# Epoch 14/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9563 - dice_coef: 0.6315 - iou: 0.4698 - loss: 0.1193 - precision: 0.8213 - recall: 0.6761
# Epoch 14: val_loss did not improve from 0.16691
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 176ms/step - accuracy: 0.9563 - dice_coef: 0.6313 - iou: 0.4696 - loss: 0.1193 - precision: 0.8212 - recall: 0.6760 - val_accuracy: 0.9346 - val_dice_coef: 0.5340 - val_iou: 0.3744 - val_loss: 0.1813 - val_precision: 0.6493 - val_recall: 0.6810 - learning_rate: 0.0010
# Epoch 15/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9554 - dice_coef: 0.6169 - iou: 0.4541 - loss: 0.1192 - precision: 0.8105 - recall: 0.6740
# Epoch 15: val_loss improved from 0.16691 to 0.14875, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 187ms/step - accuracy: 0.9554 - dice_coef: 0.6171 - iou: 0.4543 - loss: 0.1192 - precision: 0.8105 - recall: 0.6742 - val_accuracy: 0.9463 - val_dice_coef: 0.6069 - val_iou: 0.4460 - val_loss: 0.1488 - val_precision: 0.7666 - val_recall: 0.6264 - learning_rate: 0.0010
# Epoch 16/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9568 - dice_coef: 0.6437 - iou: 0.4806 - loss: 0.1123 - precision: 0.8218 - recall: 0.6779
# Epoch 16: val_loss improved from 0.14875 to 0.14379, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 195ms/step - accuracy: 0.9568 - dice_coef: 0.6437 - iou: 0.4807 - loss: 0.1123 - precision: 0.8218 - recall: 0.6781 - val_accuracy: 0.9480 - val_dice_coef: 0.6330 - val_iou: 0.4748 - val_loss: 0.1438 - val_precision: 0.7413 - val_recall: 0.6962 - learning_rate: 0.0010
# Epoch 17/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9638 - dice_coef: 0.7035 - iou: 0.5477 - loss: 0.0964 - precision: 0.8506 - recall: 0.7543
# Epoch 17: val_loss did not improve from 0.14379
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9638 - dice_coef: 0.7035 - iou: 0.5477 - loss: 0.0964 - precision: 0.8506 - recall: 0.7542 - val_accuracy: 0.9262 - val_dice_coef: 0.6199 - val_iou: 0.4592 - val_loss: 0.1913 - val_precision: 0.5770 - val_recall: 0.8425 - learning_rate: 0.0010
# Epoch 18/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9637 - dice_coef: 0.6913 - iou: 0.5336 - loss: 0.1009 - precision: 0.8481 - recall: 0.7490
# Epoch 18: val_loss did not improve from 0.14379
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9637 - dice_coef: 0.6914 - iou: 0.5336 - loss: 0.1009 - precision: 0.8481 - recall: 0.7490 - val_accuracy: 0.9415 - val_dice_coef: 0.6183 - val_iou: 0.4566 - val_loss: 0.1690 - val_precision: 0.6814 - val_recall: 0.7233 - learning_rate: 0.0010
# Epoch 19/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9631 - dice_coef: 0.6932 - iou: 0.5356 - loss: 0.0971 - precision: 0.8606 - recall: 0.7426
# Epoch 19: val_loss did not improve from 0.14379
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9631 - dice_coef: 0.6932 - iou: 0.5356 - loss: 0.0971 - precision: 0.8604 - recall: 0.7426 - val_accuracy: 0.8761 - val_dice_coef: 0.5180 - val_iou: 0.3611 - val_loss: 0.3324 - val_precision: 0.4256 - val_recall: 0.8632 - learning_rate: 0.0010
# Epoch 20/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9669 - dice_coef: 0.7139 - iou: 0.5612 - loss: 0.0874 - precision: 0.8620 - recall: 0.7679
# Epoch 20: val_loss improved from 0.14379 to 0.12914, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 185ms/step - accuracy: 0.9670 - dice_coef: 0.7142 - iou: 0.5616 - loss: 0.0873 - precision: 0.8622 - recall: 0.7682 - val_accuracy: 0.9586 - val_dice_coef: 0.6784 - val_iou: 0.5259 - val_loss: 0.1291 - val_precision: 0.8414 - val_recall: 0.6960 - learning_rate: 0.0010
# Epoch 21/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9738 - dice_coef: 0.7676 - iou: 0.6295 - loss: 0.0718 - precision: 0.8797 - recall: 0.8273
# Epoch 21: val_loss did not improve from 0.12914
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.9737 - dice_coef: 0.7676 - iou: 0.6295 - loss: 0.0718 - precision: 0.8796 - recall: 0.8273 - val_accuracy: 0.9531 - val_dice_coef: 0.6677 - val_iou: 0.5120 - val_loss: 0.1477 - val_precision: 0.7725 - val_recall: 0.7197 - learning_rate: 0.0010
# Epoch 22/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9695 - dice_coef: 0.7574 - iou: 0.6148 - loss: 0.0824 - precision: 0.8778 - recall: 0.7999
# Epoch 22: val_loss did not improve from 0.12914
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9695 - dice_coef: 0.7574 - iou: 0.6147 - loss: 0.0823 - precision: 0.8777 - recall: 0.7999 - val_accuracy: 0.9563 - val_dice_coef: 0.6705 - val_iou: 0.5161 - val_loss: 0.1425 - val_precision: 0.8690 - val_recall: 0.6365 - learning_rate: 0.0010
# Epoch 23/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9777 - dice_coef: 0.7873 - iou: 0.6531 - loss: 0.0588 - precision: 0.8884 - recall: 0.8409
# Epoch 23: val_loss did not improve from 0.12914
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9776 - dice_coef: 0.7872 - iou: 0.6530 - loss: 0.0589 - precision: 0.8884 - recall: 0.8408 - val_accuracy: 0.9393 - val_dice_coef: 0.6192 - val_iou: 0.4626 - val_loss: 0.1512 - val_precision: 0.6525 - val_recall: 0.7744 - learning_rate: 0.0010
# Epoch 24/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9750 - dice_coef: 0.7909 - iou: 0.6612 - loss: 0.0664 - precision: 0.8832 - recall: 0.8554
# Epoch 24: val_loss improved from 0.12914 to 0.12755, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 185ms/step - accuracy: 0.9749 - dice_coef: 0.7907 - iou: 0.6609 - loss: 0.0664 - precision: 0.8831 - recall: 0.8550 - val_accuracy: 0.9518 - val_dice_coef: 0.6701 - val_iou: 0.5148 - val_loss: 0.1276 - val_precision: 0.7284 - val_recall: 0.7875 - learning_rate: 0.0010
# Epoch 25/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9761 - dice_coef: 0.7977 - iou: 0.6686 - loss: 0.0632 - precision: 0.8976 - recall: 0.8424
# Epoch 25: val_loss improved from 0.12755 to 0.12138, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - accuracy: 0.9761 - dice_coef: 0.7977 - iou: 0.6686 - loss: 0.0632 - precision: 0.8976 - recall: 0.8424 - val_accuracy: 0.9611 - val_dice_coef: 0.7075 - val_iou: 0.5570 - val_loss: 0.1214 - val_precision: 0.8404 - val_recall: 0.7302 - learning_rate: 0.0010
# Epoch 26/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9775 - dice_coef: 0.8079 - iou: 0.6813 - loss: 0.0597 - precision: 0.9132 - recall: 0.8340
# Epoch 26: val_loss improved from 0.12138 to 0.10584, saving model to Polyp_resunet_model.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - accuracy: 0.9775 - dice_coef: 0.8079 - iou: 0.6813 - loss: 0.0597 - precision: 0.9131 - recall: 0.8341 - val_accuracy: 0.9657 - val_dice_coef: 0.7484 - val_iou: 0.6071 - val_loss: 0.1058 - val_precision: 0.8394 - val_recall: 0.7905 - learning_rate: 0.0010
# Epoch 27/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9785 - dice_coef: 0.7981 - iou: 0.6707 - loss: 0.0555 - precision: 0.8873 - recall: 0.8625
# Epoch 27: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.9785 - dice_coef: 0.7983 - iou: 0.6710 - loss: 0.0555 - precision: 0.8874 - recall: 0.8626 - val_accuracy: 0.9645 - val_dice_coef: 0.7516 - val_iou: 0.6127 - val_loss: 0.1434 - val_precision: 0.8825 - val_recall: 0.7239 - learning_rate: 0.0010
# Epoch 28/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9822 - dice_coef: 0.8509 - iou: 0.7441 - loss: 0.0456 - precision: 0.9086 - recall: 0.8981
# Epoch 28: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 177ms/step - accuracy: 0.9822 - dice_coef: 0.8509 - iou: 0.7441 - loss: 0.0456 - precision: 0.9087 - recall: 0.8981 - val_accuracy: 0.9646 - val_dice_coef: 0.7445 - val_iou: 0.6046 - val_loss: 0.1156 - val_precision: 0.8523 - val_recall: 0.7604 - learning_rate: 0.0010
# Epoch 29/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9835 - dice_coef: 0.8467 - iou: 0.7399 - loss: 0.0474 - precision: 0.9187 - recall: 0.8875
# Epoch 29: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9835 - dice_coef: 0.8467 - iou: 0.7398 - loss: 0.0474 - precision: 0.9187 - recall: 0.8874 - val_accuracy: 0.9554 - val_dice_coef: 0.6620 - val_iou: 0.5059 - val_loss: 0.1437 - val_precision: 0.9245 - val_recall: 0.5784 - learning_rate: 0.0010
# Epoch 30/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9823 - dice_coef: 0.8387 - iou: 0.7270 - loss: 0.0494 - precision: 0.9259 - recall: 0.8764
# Epoch 30: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9823 - dice_coef: 0.8388 - iou: 0.7271 - loss: 0.0494 - precision: 0.9259 - recall: 0.8765 - val_accuracy: 0.9411 - val_dice_coef: 0.6740 - val_iou: 0.5216 - val_loss: 0.1702 - val_precision: 0.6490 - val_recall: 0.8312 - learning_rate: 0.0010
# Epoch 31/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9847 - dice_coef: 0.8686 - iou: 0.7712 - loss: 0.0398 - precision: 0.9205 - recall: 0.9144
# Epoch 31: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 176ms/step - accuracy: 0.9847 - dice_coef: 0.8686 - iou: 0.7711 - loss: 0.0398 - precision: 0.9206 - recall: 0.9143 - val_accuracy: 0.9510 - val_dice_coef: 0.7106 - val_iou: 0.5635 - val_loss: 0.1563 - val_precision: 0.7067 - val_recall: 0.8301 - learning_rate: 0.0010
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9844 - dice_coef: 0.8699 - iou: 0.7723 - loss: 0.0415 - precision: 0.9301 - recall: 0.9088
# Epoch 32: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9844 - dice_coef: 0.8698 - iou: 0.7722 - loss: 0.0415 - precision: 0.9300 - recall: 0.9087 - val_accuracy: 0.9602 - val_dice_coef: 0.7184 - val_iou: 0.5728 - val_loss: 0.1340 - val_precision: 0.8892 - val_recall: 0.6651 - learning_rate: 0.0010
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9857 - dice_coef: 0.8783 - iou: 0.7851 - loss: 0.0367 - precision: 0.9321 - recall: 0.9130
# Epoch 33: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 176ms/step - accuracy: 0.9857 - dice_coef: 0.8782 - iou: 0.7850 - loss: 0.0368 - precision: 0.9321 - recall: 0.9130 - val_accuracy: 0.9661 - val_dice_coef: 0.7534 - val_iou: 0.6134 - val_loss: 0.1153 - val_precision: 0.9066 - val_recall: 0.7174 - learning_rate: 0.0010
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9811 - dice_coef: 0.8622 - iou: 0.7616 - loss: 0.0510 - precision: 0.9218 - recall: 0.8994
# Epoch 34: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 176ms/step - accuracy: 0.9811 - dice_coef: 0.8622 - iou: 0.7616 - loss: 0.0509 - precision: 0.9218 - recall: 0.8994 - val_accuracy: 0.9650 - val_dice_coef: 0.7589 - val_iou: 0.6269 - val_loss: 0.1424 - val_precision: 0.8995 - val_recall: 0.7113 - learning_rate: 0.0010
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9890 - dice_coef: 0.9064 - iou: 0.8299 - loss: 0.0276 - precision: 0.9497 - recall: 0.9319
# Epoch 35: val_loss did not improve from 0.10584
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 176ms/step - accuracy: 0.9890 - dice_coef: 0.9064 - iou: 0.8298 - loss: 0.0276 - precision: 0.9496 - recall: 0.9319 - val_accuracy: 0.9609 - val_dice_coef: 0.7130 - val_iou: 0.5691 - val_loss: 0.1458 - val_precision: 0.8682 - val_recall: 0.6946 - learning_rate: 0.0010
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9868 - dice_coef: 0.8901 - iou: 0.8047 - loss: 0.0337 - precision: 0.9347 - recall: 0.9284
# Epoch 36: val_loss did not improve from 0.10584
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9868 - dice_coef: 0.8902 - iou: 0.8048 - loss: 0.0337 - precision: 0.9348 - recall: 0.9284 - val_accuracy: 0.9652 - val_dice_coef: 0.7758 - val_iou: 0.6464 - val_loss: 0.1214 - val_precision: 0.8519 - val_recall: 0.7676 - learning_rate: 0.0010
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9683 - dice_coef: 0.7236 - iou: 0.5779 - loss: 0.0846 - precision: 0.7603 - recall: 0.8163
# Sample 1 Accuracy: 0.955; IoU: 0.481; Dice coef: 0.650; Recall: 0.978; Precision: 0.486
# Sample 2 Accuracy: 0.980; IoU: 0.663; Dice coef: 0.797; Recall: 0.974; Precision: 0.675
# Sample 3 Accuracy: 0.975; IoU: 0.020; Dice coef: 0.039; Recall: 0.041; Precision: 0.037

# %% [markdown]
# <font color= #gg25b2 size="4.5" face="Arial"><b>3️⃣ Project 3: Retina blood vessel Image Segmentation</b></font>

# %%
# ======================================= 1. Importing the dataset =============================================
# ------------------------------------------------ Images ------------------------------------------------------
img_format_type = "jpg"   # png, jpg, jpeg, tiff, bmp, tif, etc.
# image_path = "/content/Medical-Image-Processing/Data/Retina blood vessel/image"
image_path = "D:/Medical-Image-Processing/Data/Retina blood vessel/image/"

# Create an instance of DirectoryReader with the directory path and file format
obj_inputs = FilePathExtractor(directory_path=image_path, format_type=img_format_type)
img_filesname = obj_inputs.filesname         # List of filesname in the directory

# ------------------------------------------------ Masks -------------------------------------------------------
mask_format_type = "jpg"  # png, jpg, jpeg, tiff, bmp, tif, etc.

# mask_path = "/content/Medical-Image-Processing/Data/Retina blood vessel/mask"
mask_path = "D:/Medical-Image-Processing/Data/Retina blood vessel/mask/"

# Create an instance of DirectoryReader with the directory path and file format
obj_masks = FilePathExtractor(directory_path=mask_path, format_type=mask_format_type)
mask_filesname = obj_masks.filesname      # List of filesname in the directory

# -------------------------------------------- Check of the Images ---------------------------------------------
# Compare the base filenames (without extensions) of input files and mask files
# This line checks if the list of base filenames for input files matches the list of base filenames for mask files
[i.split(img_format_type)[0] for i in img_filesname] == [i.split(mask_format_type)[0] for i in mask_filesname]

# ============================ 2.Convert the images into array & masks to binary ===============================
# Create an instance of the `ImageProcessor` class
obj = ImageProcessor()

# Use the `read_images` method of the `ImageProcessor` object to load images from the directory
# The images are expected to be in "png or tif" format, and they are converted into a NumPy array
images = obj.read_images(image_path=image_path, format_type=img_format_type, resize=None, normalize=True)

# Use the `mask_read` method of the `ImageProcessor` object to load mask images from the directory
# The masks are expected to be in "TIF" format, and they are converted into a NumPy array
masks = obj.read_masks(mask_path=mask_path, format_type=mask_format_type, resize=None, normalize=True, num_classes=2)

ind = 20 # Set the index of the image and mask to display
plt.figure(figsize=(5, 3))
plt.subplot(121); plt.imshow(images[ind], cmap='gray'); plt.title(f'Image {ind}', fontsize=10)
plt.subplot(122); plt.imshow(masks[ind], cmap='gray'); plt.title(f'Mask {ind}', fontsize=10)
plt.tight_layout() # Adjust the layout to prevent overlap between subplots

# ===================== Prepare TensorFlow datasets for training, validation, and testing ======================
batch_size = 2

# Assuming data_resize and masks_resize are your input data and masks
train_dataset, valid_dataset, test_dataset = prepare_dataset(
    data=images,
    labels=masks,
    train_size=0.58,
    valid_size=0.25,
    batch_size=batch_size,
    shuffle_train=True,
    shuffle_buffer_size=1000,
)

# ================================================= U-Net model ================================================
# Convert any tf.placeholder usage to tf.compat.v1.placeholder
tf.placeholder = tf.compat.v1.placeholder if hasattr(tf, 'placeholder') else None
img_height, img_width, img_channels = list(train_dataset.element_spec[0].shape[1:])
model = resunet_model(img_height,
                   img_width,
                   img_channels,
                   strides=1,
                   base_filters=32,
                   kernel_size=(3, 3),
                   shortcut_kernel_size=(1, 1),
                   n_class=1,
                  )
# model.summary()

# ======================================= Segmentation Metrics & compile =======================================
metrics = segmentation_metrics(alpha=0.1)
adam = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False)
# Compile the model with custom loss and metrics
model.compile(
    optimizer=adam,               # Or 'adam', 'rmsprop'
    loss='binary_crossentropy', # Or binary_crossentropy, 'sparse_categorical_crossentropy', metrics['dice_coef_loss'], 'iou_coef_loss', 'combined_loss'
    metrics=[
        'accuracy',
        metrics['dice_coef'],
        metrics['iou'],
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision'),
        ],
    run_eagerly=False,  # Set run_eagerly=False for better performance
    )

# ================================================ Callbacks ===================================================
# csv_path = os.path.join("files", "log.csv")
csv_path = 'training_log_RetinaBloodVessel_resunet.csv'  # File to log training metrics for UNet model
model_checkpoint_path = 'RetinaBloodVessel_resunet_model.keras'  # File to save the best UNet model

callbacks = [
    CSVLogger(csv_path),  # Logs metrics to a CSV file
    ModelCheckpoint(
        filepath=model_checkpoint_path,
        monitor='val_loss',   # Monitor validation loss
        verbose=1,            # Print when saving
        save_best_only=True   # Save only when val_loss improves
    ),
    ReduceLROnPlateau(
        monitor='val_loss',   # Monitor validation loss
        factor=0.1,           # Reduce learning rate by 10x
        patience=10,          # Wait 5 epochs without improvement
        min_lr=1e-6,          # Minimum learning rate
        verbose=1             # Print when reducing LR
    ),
    EarlyStopping(
        monitor='val_loss',         # Monitor validation loss
        patience=10,                # Stop after patience epochs without improvement
        restore_best_weights=True   # Restore best weights (changed to True for better results)
    ),
    ShowImageTrainingProgress(train_dataset, sample_idx=0, figsize=(8, 3.5)),  # Show the first sample in the batch
]

# ============================================ Training the model ==============================================
# Hyperparameters
num_epochs = 100
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    callbacks=callbacks,
    validation_data=valid_dataset,
    shuffle=False,
    verbose=1,
)

# Evaluate on test set
results = model.evaluate(test_dataset, return_dict=True, verbose=1)

# ============================================ Test the model ==================================================
predictions = model.predict(test_dataset, verbose=0)
evaluate_segmentation_predictions(test_dataset=test_dataset, predictions=predictions, num_sample=2)

# ================================================ Results =====================================================
# Plot the history
plot_training_history(history, figsize=(8, 4))
plot_evaluation_results(results, figsize=(4, 4))

# Extract a small batch of data from test_dataset for visualization
for batch in test_dataset.take(1):
    test_images, test_masks = batch
    break

# Convert to numpy arrays for easier manipulation
test_images = test_images.numpy()
test_masks = test_masks.numpy()
display_predictions(test_images, test_masks, predictions, indx=0, figsize=(6, 4))
# Out:
# Image shape: (40, 512, 512, 3)
# masks.shape = (40, 512, 512, 1)
# Total number of classes in masks: 2
# Class counts in masks:
#   Class 0.00: 8278138
#   Class 1.00: 2207622
# Training set:   (23, 512, 512, 3) features, (23, 512, 512, 1) labels
# Validation set: (10, 512, 512, 3) features, (10, 512, 512, 1) labels
# Test set:       (7, 512, 512, 3) features, (7, 512, 512, 1) labels
#
# Batch size:     2
# Training shuffle: enabled
#
# (TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None))
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7255 - dice_coef: 0.3077 - iou: 0.1837 - loss: 0.7147 - precision: 0.3300 - recall: 0.2469
# Epoch 1: val_loss improved from inf to 2226.06396, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.7281 - dice_coef: 0.3079 - iou: 0.1838 - loss: 0.7043 - precision: 0.3320 - recall: 0.2428 - val_accuracy: 0.6860 - val_dice_coef: 0.0031 - val_iou: 0.0016 - val_loss: 2226.0640 - val_precision: 0.0049 - val_recall: 0.0023 - learning_rate: 0.0010
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8060 - dice_coef: 0.3454 - iou: 0.2091 - loss: 0.4097 - precision: 0.6839 - recall: 0.1345
# Epoch 2: val_loss did not improve from 2226.06396
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 533ms/step - accuracy: 0.8063 - dice_coef: 0.3464 - iou: 0.2099 - loss: 0.4095 - precision: 0.6828 - recall: 0.1377 - val_accuracy: 0.2246 - val_dice_coef: 0.3553 - val_iou: 0.2161 - val_loss: 3154.8755 - val_precision: 0.2161 - val_recall: 0.9999 - learning_rate: 0.0010
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8086 - dice_coef: 0.3767 - iou: 0.2323 - loss: 0.3978 - precision: 0.5931 - recall: 0.2587
# Epoch 3: val_loss improved from 2226.06396 to 117.12490, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 666ms/step - accuracy: 0.8091 - dice_coef: 0.3766 - iou: 0.2322 - loss: 0.3974 - precision: 0.5980 - recall: 0.2571 - val_accuracy: 0.3107 - val_dice_coef: 0.3655 - val_iou: 0.2238 - val_loss: 117.1249 - val_precision: 0.2278 - val_recall: 0.9304 - learning_rate: 0.0010
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8327 - dice_coef: 0.3855 - iou: 0.2393 - loss: 0.3837 - precision: 0.7808 - recall: 0.2611
# Epoch 4: val_loss improved from 117.12490 to 115.02500, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 721ms/step - accuracy: 0.8328 - dice_coef: 0.3875 - iou: 0.2409 - loss: 0.3833 - precision: 0.7775 - recall: 0.2652 - val_accuracy: 0.2345 - val_dice_coef: 0.3579 - val_iou: 0.2181 - val_loss: 115.0250 - val_precision: 0.2181 - val_recall: 0.9981 - learning_rate: 0.0010
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.8396 - dice_coef: 0.4298 - iou: 0.2739 - loss: 0.3662 - precision: 0.7454 - recall: 0.3360
# Epoch 5: val_loss improved from 115.02500 to 3.31157, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 674ms/step - accuracy: 0.8394 - dice_coef: 0.4304 - iou: 0.2744 - loss: 0.3663 - precision: 0.7427 - recall: 0.3378 - val_accuracy: 0.7620 - val_dice_coef: 0.0546 - val_iou: 0.0292 - val_loss: 3.3116 - val_precision: 0.1464 - val_recall: 0.0234 - learning_rate: 0.0010
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.8420 - dice_coef: 0.4220 - iou: 0.2679 - loss: 0.3638 - precision: 0.8037 - recall: 0.3204
# Epoch 6: val_loss improved from 3.31157 to 1.31075, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 675ms/step - accuracy: 0.8418 - dice_coef: 0.4222 - iou: 0.2680 - loss: 0.3640 - precision: 0.8004 - recall: 0.3215 - val_accuracy: 0.6000 - val_dice_coef: 0.4230 - val_iou: 0.2696 - val_loss: 1.3107 - val_precision: 0.3212 - val_recall: 0.7823 - learning_rate: 0.0010
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8479 - dice_coef: 0.4503 - iou: 0.2910 - loss: 0.3511 - precision: 0.7918 - recall: 0.3608
# Epoch 7: val_loss did not improve from 1.31075
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 554ms/step - accuracy: 0.8481 - dice_coef: 0.4519 - iou: 0.2923 - loss: 0.3508 - precision: 0.7901 - recall: 0.3638 - val_accuracy: 0.5414 - val_dice_coef: 0.4510 - val_iou: 0.2913 - val_loss: 2.1365 - val_precision: 0.3115 - val_recall: 0.9460 - learning_rate: 0.0010
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8559 - dice_coef: 0.4828 - iou: 0.3183 - loss: 0.3392 - precision: 0.8120 - recall: 0.4115
# Epoch 8: val_loss improved from 1.31075 to 1.22290, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 660ms/step - accuracy: 0.8559 - dice_coef: 0.4827 - iou: 0.3182 - loss: 0.3392 - precision: 0.8109 - recall: 0.4117 - val_accuracy: 0.5468 - val_dice_coef: 0.4344 - val_iou: 0.2776 - val_loss: 1.2229 - val_precision: 0.3128 - val_recall: 0.9354 - learning_rate: 0.0010
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8609 - dice_coef: 0.4887 - iou: 0.3236 - loss: 0.3346 - precision: 0.8010 - recall: 0.4384
# Epoch 9: val_loss improved from 1.22290 to 0.91005, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 649ms/step - accuracy: 0.8607 - dice_coef: 0.4885 - iou: 0.3234 - loss: 0.3348 - precision: 0.8005 - recall: 0.4378 - val_accuracy: 0.5561 - val_dice_coef: 0.4065 - val_iou: 0.2552 - val_loss: 0.9101 - val_precision: 0.3148 - val_recall: 0.9150 - learning_rate: 0.0010
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8602 - dice_coef: 0.5061 - iou: 0.3390 - loss: 0.3264 - precision: 0.7991 - recall: 0.4415
# Epoch 10: val_loss improved from 0.91005 to 0.57734, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 650ms/step - accuracy: 0.8601 - dice_coef: 0.5067 - iou: 0.3396 - loss: 0.3264 - precision: 0.7969 - recall: 0.4433 - val_accuracy: 0.6613 - val_dice_coef: 0.3573 - val_iou: 0.2176 - val_loss: 0.5773 - val_precision: 0.3436 - val_recall: 0.6418 - learning_rate: 0.0010
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8673 - dice_coef: 0.5086 - iou: 0.3412 - loss: 0.3138 - precision: 0.8136 - recall: 0.4546
# Epoch 11: val_loss improved from 0.57734 to 0.57377, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 726ms/step - accuracy: 0.8670 - dice_coef: 0.5090 - iou: 0.3416 - loss: 0.3143 - precision: 0.8118 - recall: 0.4559 - val_accuracy: 0.6947 - val_dice_coef: 0.3463 - val_iou: 0.2096 - val_loss: 0.5738 - val_precision: 0.3489 - val_recall: 0.4942 - learning_rate: 0.0010
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8644 - dice_coef: 0.5238 - iou: 0.3549 - loss: 0.3168 - precision: 0.7949 - recall: 0.4738
# Epoch 12: val_loss improved from 0.57377 to 0.53641, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 657ms/step - accuracy: 0.8643 - dice_coef: 0.5234 - iou: 0.3546 - loss: 0.3170 - precision: 0.7944 - recall: 0.4733 - val_accuracy: 0.7446 - val_dice_coef: 0.3518 - val_iou: 0.2135 - val_loss: 0.5364 - val_precision: 0.4230 - val_recall: 0.5343 - learning_rate: 0.0010
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8723 - dice_coef: 0.5289 - iou: 0.3602 - loss: 0.3029 - precision: 0.7760 - recall: 0.5110
# Epoch 13: val_loss improved from 0.53641 to 0.51509, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 665ms/step - accuracy: 0.8720 - dice_coef: 0.5301 - iou: 0.3612 - loss: 0.3033 - precision: 0.7764 - recall: 0.5109 - val_accuracy: 0.7650 - val_dice_coef: 0.3602 - val_iou: 0.2198 - val_loss: 0.5151 - val_precision: 0.4558 - val_recall: 0.5103 - learning_rate: 0.0010
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8633 - dice_coef: 0.5332 - iou: 0.3635 - loss: 0.3161 - precision: 0.7686 - recall: 0.5264
# Epoch 14: val_loss did not improve from 0.51509
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.8637 - dice_coef: 0.5335 - iou: 0.3638 - loss: 0.3153 - precision: 0.7695 - recall: 0.5254 - val_accuracy: 0.7782 - val_dice_coef: 0.2390 - val_iou: 0.1359 - val_loss: 0.5213 - val_precision: 0.3573 - val_recall: 0.0464 - learning_rate: 0.0010
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8679 - dice_coef: 0.5353 - iou: 0.3658 - loss: 0.3030 - precision: 0.7694 - recall: 0.5010
# Epoch 15: val_loss improved from 0.51509 to 0.47929, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 660ms/step - accuracy: 0.8680 - dice_coef: 0.5362 - iou: 0.3667 - loss: 0.3027 - precision: 0.7704 - recall: 0.5022 - val_accuracy: 0.7920 - val_dice_coef: 0.2909 - val_iou: 0.1703 - val_loss: 0.4793 - val_precision: 0.5712 - val_recall: 0.1102 - learning_rate: 0.0010
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8702 - dice_coef: 0.5575 - iou: 0.3866 - loss: 0.2966 - precision: 0.7825 - recall: 0.5252
# Epoch 16: val_loss did not improve from 0.47929
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 550ms/step - accuracy: 0.8703 - dice_coef: 0.5575 - iou: 0.3866 - loss: 0.2964 - precision: 0.7828 - recall: 0.5252 - val_accuracy: 0.7809 - val_dice_coef: 0.2383 - val_iou: 0.1354 - val_loss: 0.5251 - val_precision: 0.4135 - val_recall: 0.0591 - learning_rate: 0.0010
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8696 - dice_coef: 0.5666 - iou: 0.3955 - loss: 0.2935 - precision: 0.7843 - recall: 0.5298
# Epoch 17: val_loss did not improve from 0.47929
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 0.8696 - dice_coef: 0.5662 - iou: 0.3951 - loss: 0.2934 - precision: 0.7837 - recall: 0.5301 - val_accuracy: 0.7879 - val_dice_coef: 0.2700 - val_iou: 0.1561 - val_loss: 0.4845 - val_precision: 0.5294 - val_recall: 0.0744 - learning_rate: 0.0010
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8705 - dice_coef: 0.5612 - iou: 0.3903 - loss: 0.2921 - precision: 0.8070 - recall: 0.5015
# Epoch 18: val_loss did not improve from 0.47929
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 537ms/step - accuracy: 0.8706 - dice_coef: 0.5616 - iou: 0.3906 - loss: 0.2919 - precision: 0.8057 - recall: 0.5033 - val_accuracy: 0.7882 - val_dice_coef: 0.2361 - val_iou: 0.1341 - val_loss: 0.5175 - val_precision: 0.5342 - val_recall: 0.0732 - learning_rate: 0.0010
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8714 - dice_coef: 0.5639 - iou: 0.3932 - loss: 0.2873 - precision: 0.7930 - recall: 0.5153
# Epoch 19: val_loss improved from 0.47929 to 0.45868, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 655ms/step - accuracy: 0.8715 - dice_coef: 0.5642 - iou: 0.3935 - loss: 0.2871 - precision: 0.7926 - recall: 0.5164 - val_accuracy: 0.8004 - val_dice_coef: 0.2920 - val_iou: 0.1711 - val_loss: 0.4587 - val_precision: 0.7090 - val_recall: 0.1126 - learning_rate: 0.0010
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8697 - dice_coef: 0.5643 - iou: 0.3931 - loss: 0.2928 - precision: 0.8009 - recall: 0.5080
# Epoch 20: val_loss improved from 0.45868 to 0.45141, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 660ms/step - accuracy: 0.8699 - dice_coef: 0.5648 - iou: 0.3935 - loss: 0.2922 - precision: 0.8008 - recall: 0.5091 - val_accuracy: 0.8070 - val_dice_coef: 0.3079 - val_iou: 0.1821 - val_loss: 0.4514 - val_precision: 0.7636 - val_recall: 0.1409 - learning_rate: 0.0010
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8690 - dice_coef: 0.5758 - iou: 0.4044 - loss: 0.2895 - precision: 0.7712 - recall: 0.5497
# Epoch 21: val_loss improved from 0.45141 to 0.42550, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 675ms/step - accuracy: 0.8693 - dice_coef: 0.5757 - iou: 0.4043 - loss: 0.2890 - precision: 0.7719 - recall: 0.5492 - val_accuracy: 0.8087 - val_dice_coef: 0.3280 - val_iou: 0.1963 - val_loss: 0.4255 - val_precision: 0.7700 - val_recall: 0.1503 - learning_rate: 0.0010
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8725 - dice_coef: 0.5773 - iou: 0.4059 - loss: 0.2849 - precision: 0.7971 - recall: 0.5292
# Epoch 22: val_loss did not improve from 0.42550
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 539ms/step - accuracy: 0.8726 - dice_coef: 0.5775 - iou: 0.4060 - loss: 0.2846 - precision: 0.7969 - recall: 0.5296 - val_accuracy: 0.7978 - val_dice_coef: 0.2698 - val_iou: 0.1562 - val_loss: 0.4896 - val_precision: 0.6739 - val_recall: 0.1051 - learning_rate: 0.0010
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8712 - dice_coef: 0.5751 - iou: 0.4037 - loss: 0.2897 - precision: 0.7958 - recall: 0.5231
# Epoch 23: val_loss did not improve from 0.42550
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 558ms/step - accuracy: 0.8713 - dice_coef: 0.5750 - iou: 0.4036 - loss: 0.2894 - precision: 0.7957 - recall: 0.5234 - val_accuracy: 0.8017 - val_dice_coef: 0.3082 - val_iou: 0.1823 - val_loss: 0.4390 - val_precision: 0.7015 - val_recall: 0.1263 - learning_rate: 0.0010
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8727 - dice_coef: 0.5811 - iou: 0.4098 - loss: 0.2868 - precision: 0.7858 - recall: 0.5352
# Epoch 24: val_loss improved from 0.42550 to 0.40914, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 654ms/step - accuracy: 0.8728 - dice_coef: 0.5812 - iou: 0.4099 - loss: 0.2868 - precision: 0.7865 - recall: 0.5351 - val_accuracy: 0.8221 - val_dice_coef: 0.3632 - val_iou: 0.2221 - val_loss: 0.4091 - val_precision: 0.8175 - val_recall: 0.2162 - learning_rate: 0.0010
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8740 - dice_coef: 0.5691 - iou: 0.3979 - loss: 0.2829 - precision: 0.7563 - recall: 0.5667
# Epoch 25: val_loss improved from 0.40914 to 0.35999, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 658ms/step - accuracy: 0.8739 - dice_coef: 0.5696 - iou: 0.3984 - loss: 0.2832 - precision: 0.7574 - recall: 0.5656 - val_accuracy: 0.8478 - val_dice_coef: 0.4347 - val_iou: 0.2779 - val_loss: 0.3600 - val_precision: 0.8515 - val_recall: 0.3489 - learning_rate: 0.0010
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.8753 - dice_coef: 0.5761 - iou: 0.4048 - loss: 0.2774 - precision: 0.7999 - recall: 0.5401
# Epoch 26: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 541ms/step - accuracy: 0.8753 - dice_coef: 0.5764 - iou: 0.4051 - loss: 0.2773 - precision: 0.7990 - recall: 0.5404 - val_accuracy: 0.8193 - val_dice_coef: 0.3731 - val_iou: 0.2296 - val_loss: 0.4024 - val_precision: 0.7459 - val_recall: 0.2350 - learning_rate: 0.0010
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8776 - dice_coef: 0.5926 - iou: 0.4211 - loss: 0.2699 - precision: 0.8179 - recall: 0.5349
# Epoch 27: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 551ms/step - accuracy: 0.8775 - dice_coef: 0.5924 - iou: 0.4209 - loss: 0.2700 - precision: 0.8169 - recall: 0.5352 - val_accuracy: 0.8248 - val_dice_coef: 0.4014 - val_iou: 0.2515 - val_loss: 0.3753 - val_precision: 0.7807 - val_recall: 0.2510 - learning_rate: 0.0010
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.8756 - dice_coef: 0.5977 - iou: 0.4264 - loss: 0.2723 - precision: 0.7943 - recall: 0.5611
# Epoch 28: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 532ms/step - accuracy: 0.8758 - dice_coef: 0.5974 - iou: 0.4261 - loss: 0.2719 - precision: 0.7945 - recall: 0.5605 - val_accuracy: 0.8216 - val_dice_coef: 0.3844 - val_iou: 0.2385 - val_loss: 0.3909 - val_precision: 0.8376 - val_recall: 0.2057 - learning_rate: 0.0010
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8776 - dice_coef: 0.6003 - iou: 0.4290 - loss: 0.2676 - precision: 0.8099 - recall: 0.5439
# Epoch 29: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 543ms/step - accuracy: 0.8777 - dice_coef: 0.6000 - iou: 0.4287 - loss: 0.2675 - precision: 0.8095 - recall: 0.5441 - val_accuracy: 0.8234 - val_dice_coef: 0.3957 - val_iou: 0.2471 - val_loss: 0.3742 - val_precision: 0.8345 - val_recall: 0.2171 - learning_rate: 0.0010
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8822 - dice_coef: 0.6004 - iou: 0.4292 - loss: 0.2574 - precision: 0.8007 - recall: 0.5611
# Epoch 30: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 616ms/step - accuracy: 0.8819 - dice_coef: 0.6003 - iou: 0.4291 - loss: 0.2579 - precision: 0.8007 - recall: 0.5606 - val_accuracy: 0.8268 - val_dice_coef: 0.4030 - val_iou: 0.2528 - val_loss: 0.3887 - val_precision: 0.7924 - val_recall: 0.2576 - learning_rate: 0.0010
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8814 - dice_coef: 0.6031 - iou: 0.4319 - loss: 0.2560 - precision: 0.8066 - recall: 0.5596
# Epoch 31: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 0.8812 - dice_coef: 0.6032 - iou: 0.4320 - loss: 0.2564 - precision: 0.8062 - recall: 0.5597 - val_accuracy: 0.8281 - val_dice_coef: 0.4080 - val_iou: 0.2567 - val_loss: 0.3704 - val_precision: 0.8656 - val_recall: 0.2319 - learning_rate: 0.0010
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.8776 - dice_coef: 0.6041 - iou: 0.4329 - loss: 0.2633 - precision: 0.8181 - recall: 0.5480
# Epoch 32: val_loss did not improve from 0.35999
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 543ms/step - accuracy: 0.8777 - dice_coef: 0.6039 - iou: 0.4327 - loss: 0.2632 - precision: 0.8171 - recall: 0.5485 - val_accuracy: 0.8181 - val_dice_coef: 0.3602 - val_iou: 0.2200 - val_loss: 0.4389 - val_precision: 0.7145 - val_recall: 0.2486 - learning_rate: 0.0010
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8835 - dice_coef: 0.6020 - iou: 0.4308 - loss: 0.2509 - precision: 0.8235 - recall: 0.5420
# Epoch 33: val_loss improved from 0.35999 to 0.33234, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 715ms/step - accuracy: 0.8833 - dice_coef: 0.6024 - iou: 0.4311 - loss: 0.2513 - precision: 0.8231 - recall: 0.5427 - val_accuracy: 0.8469 - val_dice_coef: 0.4666 - val_iou: 0.3046 - val_loss: 0.3323 - val_precision: 0.8636 - val_recall: 0.3372 - learning_rate: 0.0010
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8783 - dice_coef: 0.6065 - iou: 0.4353 - loss: 0.2594 - precision: 0.7953 - recall: 0.5674
# Epoch 34: val_loss did not improve from 0.33234
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 540ms/step - accuracy: 0.8785 - dice_coef: 0.6071 - iou: 0.4359 - loss: 0.2589 - precision: 0.7957 - recall: 0.5676 - val_accuracy: 0.8393 - val_dice_coef: 0.4577 - val_iou: 0.2972 - val_loss: 0.3478 - val_precision: 0.8375 - val_recall: 0.3083 - learning_rate: 0.0010
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8844 - dice_coef: 0.6169 - iou: 0.4461 - loss: 0.2453 - precision: 0.8137 - recall: 0.5633
# Epoch 35: val_loss improved from 0.33234 to 0.32845, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 666ms/step - accuracy: 0.8842 - dice_coef: 0.6169 - iou: 0.4462 - loss: 0.2457 - precision: 0.8132 - recall: 0.5637 - val_accuracy: 0.8498 - val_dice_coef: 0.4987 - val_iou: 0.3325 - val_loss: 0.3285 - val_precision: 0.7993 - val_recall: 0.3975 - learning_rate: 0.0010
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8854 - dice_coef: 0.6202 - iou: 0.4495 - loss: 0.2418 - precision: 0.8090 - recall: 0.5749
# Epoch 36: val_loss did not improve from 0.32845
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 537ms/step - accuracy: 0.8851 - dice_coef: 0.6199 - iou: 0.4493 - loss: 0.2423 - precision: 0.8087 - recall: 0.5745 - val_accuracy: 0.8516 - val_dice_coef: 0.4826 - val_iou: 0.3185 - val_loss: 0.3497 - val_precision: 0.8970 - val_recall: 0.3459 - learning_rate: 0.0010
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8804 - dice_coef: 0.6124 - iou: 0.4414 - loss: 0.2540 - precision: 0.8117 - recall: 0.5626
# Epoch 37: val_loss did not improve from 0.32845
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 557ms/step - accuracy: 0.8805 - dice_coef: 0.6128 - iou: 0.4418 - loss: 0.2536 - precision: 0.8114 - recall: 0.5630 - val_accuracy: 0.8490 - val_dice_coef: 0.4807 - val_iou: 0.3169 - val_loss: 0.3336 - val_precision: 0.9030 - val_recall: 0.3294 - learning_rate: 0.0010
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.8870 - dice_coef: 0.6267 - iou: 0.4564 - loss: 0.2349 - precision: 0.8179 - recall: 0.5735
# Epoch 38: val_loss improved from 0.32845 to 0.30841, saving model to RetinaBloodVessel_resunet_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 664ms/step - accuracy: 0.8867 - dice_coef: 0.6265 - iou: 0.4562 - loss: 0.2355 - precision: 0.8181 - recall: 0.5727 - val_accuracy: 0.8629 - val_dice_coef: 0.5188 - val_iou: 0.3506 - val_loss: 0.3084 - val_precision: 0.8565 - val_recall: 0.4311 - learning_rate: 0.0010
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8768 - dice_coef: 0.6295 - iou: 0.4595 - loss: 0.2491 - precision: 0.7413 - recall: 0.6502
# Epoch 39: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.8771 - dice_coef: 0.6293 - iou: 0.4593 - loss: 0.2486 - precision: 0.7435 - recall: 0.6473 - val_accuracy: 0.8577 - val_dice_coef: 0.5124 - val_iou: 0.3449 - val_loss: 0.3444 - val_precision: 0.9071 - val_recall: 0.3727 - learning_rate: 0.0010
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.8801 - dice_coef: 0.6269 - iou: 0.4566 - loss: 0.2423 - precision: 0.8105 - recall: 0.5723
# Epoch 40: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 549ms/step - accuracy: 0.8803 - dice_coef: 0.6270 - iou: 0.4567 - loss: 0.2421 - precision: 0.8093 - recall: 0.5733 - val_accuracy: 0.8584 - val_dice_coef: 0.5202 - val_iou: 0.3521 - val_loss: 0.3385 - val_precision: 0.9172 - val_recall: 0.3714 - learning_rate: 0.0010
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step - accuracy: 0.8860 - dice_coef: 0.6404 - iou: 0.4711 - loss: 0.2295 - precision: 0.8068 - recall: 0.5954
# Epoch 41: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 551ms/step - accuracy: 0.8860 - dice_coef: 0.6403 - iou: 0.4709 - loss: 0.2296 - precision: 0.8069 - recall: 0.5950 - val_accuracy: 0.8528 - val_dice_coef: 0.5018 - val_iou: 0.3354 - val_loss: 0.3606 - val_precision: 0.9519 - val_recall: 0.3281 - learning_rate: 0.0010
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.8872 - dice_coef: 0.6466 - iou: 0.4778 - loss: 0.2250 - precision: 0.8164 - recall: 0.5914
# Epoch 42: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 565ms/step - accuracy: 0.8871 - dice_coef: 0.6465 - iou: 0.4777 - loss: 0.2251 - precision: 0.8155 - recall: 0.5921 - val_accuracy: 0.8474 - val_dice_coef: 0.4842 - val_iou: 0.3200 - val_loss: 0.3572 - val_precision: 0.9643 - val_recall: 0.2974 - learning_rate: 0.0010
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8862 - dice_coef: 0.6370 - iou: 0.4674 - loss: 0.2288 - precision: 0.8195 - recall: 0.5810
# Epoch 43: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 534ms/step - accuracy: 0.8861 - dice_coef: 0.6371 - iou: 0.4676 - loss: 0.2289 - precision: 0.8185 - recall: 0.5817 - val_accuracy: 0.8610 - val_dice_coef: 0.5303 - val_iou: 0.3613 - val_loss: 0.3495 - val_precision: 0.9243 - val_recall: 0.3811 - learning_rate: 0.0010
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8891 - dice_coef: 0.6468 - iou: 0.4781 - loss: 0.2164 - precision: 0.7824 - recall: 0.6195
# Epoch 44: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 546ms/step - accuracy: 0.8889 - dice_coef: 0.6470 - iou: 0.4783 - loss: 0.2168 - precision: 0.7835 - recall: 0.6188 - val_accuracy: 0.8612 - val_dice_coef: 0.5322 - val_iou: 0.3630 - val_loss: 0.3609 - val_precision: 0.9290 - val_recall: 0.3798 - learning_rate: 0.0010
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8916 - dice_coef: 0.6518 - iou: 0.4836 - loss: 0.2108 - precision: 0.7911 - recall: 0.6192
# Epoch 45: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 609ms/step - accuracy: 0.8912 - dice_coef: 0.6519 - iou: 0.4836 - loss: 0.2114 - precision: 0.7913 - recall: 0.6190 - val_accuracy: 0.8610 - val_dice_coef: 0.5351 - val_iou: 0.3658 - val_loss: 0.3436 - val_precision: 0.9425 - val_recall: 0.3725 - learning_rate: 0.0010
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8855 - dice_coef: 0.6572 - iou: 0.4895 - loss: 0.2180 - precision: 0.8099 - recall: 0.6056
# Epoch 46: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 534ms/step - accuracy: 0.8857 - dice_coef: 0.6571 - iou: 0.4894 - loss: 0.2177 - precision: 0.8097 - recall: 0.6060 - val_accuracy: 0.8560 - val_dice_coef: 0.5127 - val_iou: 0.3453 - val_loss: 0.3669 - val_precision: 0.9514 - val_recall: 0.3439 - learning_rate: 0.0010
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.8896 - dice_coef: 0.6531 - iou: 0.4850 - loss: 0.2128 - precision: 0.8175 - recall: 0.5995
# Epoch 47: val_loss did not improve from 0.30841
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 541ms/step - accuracy: 0.8894 - dice_coef: 0.6533 - iou: 0.4852 - loss: 0.2131 - precision: 0.8159 - recall: 0.6008 - val_accuracy: 0.8612 - val_dice_coef: 0.5396 - val_iou: 0.3707 - val_loss: 0.3918 - val_precision: 0.9002 - val_recall: 0.3945 - learning_rate: 0.0010
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.8907 - dice_coef: 0.6484 - iou: 0.4798 - loss: 0.2119 - precision: 0.8095 - recall: 0.5968
# Epoch 48: val_loss did not improve from 0.30841
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 0.8905 - dice_coef: 0.6489 - iou: 0.4804 - loss: 0.2122 - precision: 0.8091 - recall: 0.5978 - val_accuracy: 0.8591 - val_dice_coef: 0.5290 - val_iou: 0.3604 - val_loss: 0.4165 - val_precision: 0.9332 - val_recall: 0.3674 - learning_rate: 0.0010
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 636ms/step - accuracy: 0.8644 - dice_coef: 0.4987 - iou: 0.3323 - loss: 0.3098 - precision: 0.8922 - recall: 0.3928
# Sample 1 Accuracy: 0.873; IoU: 0.394; Dice coef: 0.566; Recall: 0.414; Precision: 0.892
# Sample 2 Accuracy: 0.871; IoU: 0.370; Dice coef: 0.540; Recall: 0.387; Precision: 0.891
