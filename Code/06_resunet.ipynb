# %% [markdown]
# ***Welcome to Medical image processing in Python***<br/>
#
# Presented by: Reza Saadatyar (2024-2025) <br/>
# E-mail: Reza.Saadatyar@outlook.com<br/>
# **[GitHub](https://github.com/RezaSaadatyar/Deep-Learning-in-python)**

# %% [markdown]
# [Deep Residual U-Net](https://arxiv.org/pdf/1711.10684)<br/>
# ResUNet is a semantic segmentation model that combines the strengths of deep residual learning and the UNet architecture. It leverages residual connections to facilitate efficient gradient flow and deeper network training while incorporating the UNet’s encoder-decoder structure to capture fine-grained spatial details and context for precise segmentation. This hybrid design enables ResUNet to handle complex segmentation tasks with improved accuracy and robustness.
#
# **Outline:**<br/>
# **▪ Importing the dataset**<br/>
# **▪ Convert the images into array & masks to binary**<br/>
# **▪ [Prepare TensorFlow datasets for training, validation, and testing](https://github.com/RezaSaadatyar/Deep-Learning-in-python/blob/main/Code/02_tensorflow_data_loading_and_processing.ipynb)**<br/>
# **▪ Deep Residual U-Net Architectur**<br/>
# **▪ Segmentation Metrics**<br/>
# **▪ Callbacks**<br/>
# **▪ Training the model**<br/>
# **▪ Test the model**<br/>
# **▪ Load previously trained Model**

# %%
# This code is specifically designed for Google Colab environment
# It clones a GitHub repository containing medical image processing code and sets up the environment

# Clone the Medical-Image-Processing repository from GitHub using git command
# In Colab, this will clone into the /content directory by default
# !git clone https://github.com/RezaSaadatyar/Medical-Image-Processing

# List contents of the cloned repository directory to verify successful cloning
# Colab's !ls command shows files in the current directory
# !ls /content/Medical-Image-Processing

# Change working directory to the Code subdirectory of the cloned repository
# %cd is a Colab magic command to change directories
# %cd /content/Medical-Image-Processing/Code

# Import Python's system module for path manipulation
import sys

# Add the Functions subdirectory to Python's system path for module imports
# This allows importing custom modules from the cloned repository
sys.path.append('/content/Medical-Image-Processing/Code/Functions')

# Install the colorama package using pip for colored terminal text
# Colab's !pip install installs packages in the current runtime environment
! pip install colorama
# Out:
# Cloning into 'Medical-Image-Processing'...
# remote: Enumerating objects: 8929, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 8929 (delta 4), reused 9 (delta 3), pack-reused 8914 (from 2)
# Receiving objects: 100% (8929/8929), 984.00 MiB | 36.74 MiB/s, done.
# Resolving deltas: 100% (3232/3232), done.
# Updating files: 100% (7742/7742), done.
# Code  Data  Image  LICENSE  README.md  Results
# /content/Medical-Image-Processing/Code
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %% [markdown]
# <font color='#FF000e' size="4.8" face="Arial"><b>Importing libraries</b></font>

# %%
import pprint
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple, Union

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import CSVLogger, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Input, Lambda, Conv2D, BatchNormalization, Activation, Add, UpSampling2D, concatenate

from Functions.image_processor import ImageProcessor
from Functions.filepath_extractor import FilePathExtractor

# %% [markdown]
# <font color=#eff30b size="4.5" face="Arial"><b>1️⃣ Importing the dataset</b></font>

# %%
# ================================================ Images ======================================================
img_format_type = "png"   # png, jpg, jpeg, tiff, bmp, tif, etc.
image_path = "D:/Medical-Image-Processing/Data/Membrance/images/"
# image_path = "/content/Medical-Image-Processing/Data/Membrance/images"

# Create an instance of DirectoryReader with the directory path and file format
obj_inputs = FilePathExtractor(directory_path=image_path, format_type=img_format_type)
img_filesname = obj_inputs.filesname         # List of filesname in the directory

pprint.pprint({"Image files": img_filesname}, compact=True, width=120)
# Out:
# {'Image files': ['0.png', '1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png', '10.png',
#                  '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png',
#                  '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png']}

# %%
# ==================================================== Masks ===================================================
mask_format_type = "png"  # png, jpg, jpeg, tiff, bmp, tif, etc.

mask_path = "D:/Medical-Image-Processing/Data/Membrance/masks/"
# mask_path = "/content/Medical-Image-Processing/Data/Membrance/masks"

# Create an instance of DirectoryReader with the directory path and file format
obj_masks = FilePathExtractor(directory_path=mask_path, format_type=mask_format_type)
mask_filesname = obj_masks.filesname      # List of filesname in the directory
files_path = obj_masks.all_files_path
pprint.pprint({"Mask files": mask_filesname}, compact=True, width=120)
# Out:
# {'Mask files': ['0.png', '1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png', '10.png',
#                 '11.png', '12.png', '13.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png',
#                 '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png']}

# %%
# ============================================ Check of the Images =============================================
# Compare the base filenames (without extensions) of input files and mask files
# This line checks if the list of base filenames for input files matches the list of base filenames for mask files
[i.split(img_format_type)[0] for i in img_filesname] == [i.split(mask_format_type)[0] for i in mask_filesname]
# Out:
# True

# %% [markdown]
# <font color=#09eb14 size="4.5" face="Arial"><b> 2️⃣ Convert the images into array & masks to binary</b></font>

# %%
# ================================================ Images ======================================================
# Create an instance of the `ImageProcessor` class
obj = ImageProcessor()

# Use the `read_images` method of the `ImageProcessor` object to load images from the directory
# The images are expected to be in "png or tif" format, and they are converted into a NumPy array
images = obj.read_images(image_path=image_path, format_type=img_format_type, resize=None, normalize=True)
# Out:
# Image shape: (30, 512, 512, 1)

# %%
# ==================================================== Masks ===================================================
# Use the `mask_read` method of the `ImageProcessor` object to load mask images from the directory
# The masks are expected to be in "TIF" format, and they are converted into a NumPy array
masks = obj.read_masks(mask_path=mask_path, format_type=mask_format_type, resize=None, normalize=True, num_classes=2)
# Out:
# masks.shape = (30, 512, 512, 1)
# Total number of classes in masks: 2
# Class counts in masks:
#   Class 0.00: 1727250
#   Class 1.00: 6137070

# %%
idx = 20 # Set the index of the image and mask to display
plt.figure(figsize=(5, 3))
plt.subplot(121); plt.imshow(images[idx], cmap='gray'); plt.title(f'Image {idx}', fontsize=10)
plt.subplot(122); plt.imshow(masks[idx], cmap='gray'); plt.title(f'Mask {idx}', fontsize=10)
plt.tight_layout() # Adjust the layout to prevent overlap between subplots

# %% [markdown]
# <font color=#ee0caa size="4.5" face="Arial"><b>3️⃣ [Prepare TensorFlow datasets for training, validation, and testing](https://github.com/RezaSaadatyar/Deep-Learning-in-python/blob/main/Code/02_tensorflow_data_loading_and_processing.ipynb)</b></font>

# %%
def prepare_dataset(
    data: Union[np.ndarray, tf.Tensor],
    labels: Union[np.ndarray, tf.Tensor],
    train_size: float = 0.7,
    valid_size: float = 0.15,
    batch_size: int = 8,
    shuffle_train: bool = True,
    shuffle_buffer_size: int = 1000
) -> Tuple[tf.data.Dataset, tf.data.Dataset, tf.data.Dataset]:
    """
    This function handles the complete pipeline from raw data to optimized TensorFlow Dataset objects,
    including data splitting, shuffling, batching, and prefetching for optimal performance.

    Args:
        data: Input features as either numpy array or TensorFlow tensor
               Shape should be (num_samples, ...features_dims)
        labels: Corresponding labels as either numpy array or TensorFlow tensor
                Shape should be (num_samples, ...label_dims)
        train_size: Proportion of data for training
        valid_size: Proportion of data for validation
        batch_size: Number of samples per batch (positive integer)
        shuffle_train: Whether to shuffle training data
        shuffle_buffer_size: Size of buffer used for shuffling (larger = better shuffling but more memory)

    Returns:
        Tuple of (train_dataset, valid_dataset, test_dataset)
    """

    # Validate split proportions
    if train_size + valid_size > 1.0: raise ValueError("train_size + valid_size must not exceed 1.0")
    if train_size < valid_size: raise ValueError("Training set should typically be larger than validation set")

    # Convert TensorFlow tensors to numpy arrays
    if tf.is_tensor(data): data = data.numpy()
    if tf.is_tensor(labels): labels = labels.numpy()

    # Verify data and labels compatibility
    if len(data) != len(labels):
        raise ValueError(f"Mismatched lengths: data has {len(data)} samples but labels has {len(labels)}")

    # Normalize images to [0, 1]
    if data.max() > 1.0:  # Assuming data is in [0, 255]
        data = data / 255.0

    # ======================================== DATA SPLITTING ==================================================
    # First split separates test set from training+validation
    x_train_val, x_test, y_train_val, y_test = train_test_split(
        data,
        labels,
        train_size=train_size + valid_size,  # Combined size for train+val
        test_size=1.0 - (train_size + valid_size),  # Remainder for test
        random_state=24,  # Fixed seed for reproducibility
        # stratify=labels if len(set(labels)) > 1 else None  # Optional stratification
    )

    # Second split divides train+val into separate sets
    # Calculate relative proportion of validation within train+val subset
    valid_proportion = valid_size / (train_size + valid_size)
    x_train, x_valid, y_train, y_valid = train_test_split(
        x_train_val,
        y_train_val,
        train_size=1.0 - valid_proportion,  # Relative train size
        test_size=valid_proportion,          # Relative validation size
        random_state=24,  # Same seed for consistency
        # stratify=y_train_val if len(set(y_train_val)) > 1 else None
    )

    # ======================================= DATASET CREATION =================================================
    # Create TensorFlow Dataset objects with proper type casting
    train_dataset = tf.data.Dataset.from_tensor_slices(
        (tf.cast(x_train, tf.float32),  # Convert features to float32
        tf.cast(y_train, tf.float32)    # Convert labels to float32
    ))

    valid_dataset = tf.data.Dataset.from_tensor_slices(
        (tf.cast(x_valid, tf.float32), tf.cast(y_valid, tf.float32))
    )
    test_dataset = tf.data.Dataset.from_tensor_slices(
        (tf.cast(x_test, tf.float32), tf.cast(y_test, tf.float32))
    )

    # ====================================== DATASET OPTIMIZATION ==============================================
    # Shuffle training data if enabled (recommended for better training)
    if shuffle_train:
        train_dataset = train_dataset.shuffle(
            buffer_size=min(shuffle_buffer_size, len(x_train)),  # Don't exceed dataset size
            reshuffle_each_iteration=True  # Important for proper epoch training
        )

    # Batch all datasets for efficient processing
    train_dataset = train_dataset.batch(batch_size)
    valid_dataset = valid_dataset.batch(batch_size)
    test_dataset = test_dataset.batch(batch_size)

    # Prefetch data to overlap preprocessing and model execution
    train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)  # Let TensorFlow optimize buffer size
    valid_dataset = valid_dataset.prefetch(tf.data.AUTOTUNE)
    test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

    # Print dataset info
    print(f"Training set:   {x_train.shape} features, {y_train.shape} labels")
    print(f"Validation set: {x_valid.shape} features, {y_valid.shape} labels")
    print(f"Test set:       {x_test.shape} features, {y_test.shape} labels")
    print(f"\nBatch size:     {batch_size}")
    print(f"Training shuffle: {'enabled' if shuffle_train else 'disabled'}")
    print("\t")
    pprint.pprint(train_dataset.element_spec, width=80)

    return train_dataset, valid_dataset, test_dataset

# %%
batch_size = 4

# Assuming data_resize and masks_resize are your input data and masks
train_dataset, valid_dataset, test_dataset = prepare_dataset(
    data=images,
    labels=masks,
    train_size=0.6,
    valid_size=0.25,
    batch_size=batch_size,
    shuffle_train=True,
    shuffle_buffer_size=1000,
)
# Out:
# Training set:   (17, 512, 512, 1) features, (17, 512, 512, 1) labels
# Validation set: (8, 512, 512, 1) features, (8, 512, 512, 1) labels
# Test set:       (5, 512, 512, 1) features, (5, 512, 512, 1) labels
#
# Batch size:     4
# Training shuffle: enabled
#
# (TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32, name=None))

# %%
# Convert the validation dataset to a list of numpy arrays
list(valid_dataset.as_numpy_iterator())
# or
# Iterate over the first 1 elements of the dataset and print each pair of (x, y) values
for ind_x, ind_y in valid_dataset.take(1):
    # Print the input and output tensors in a formatted string
    print(f"Image:\n{ind_x}")
# Out:
# Image:
# [[[[0.70980394]
#    [0.6745098 ]
#    [0.6627451 ]
#    ...
#    [0.47843137]
#    [0.3137255 ]
#    [0.3019608 ]]
#
#   [[0.72156864]
#    [0.7137255 ]
#    [0.6509804 ]
#    ...
#    [0.3254902 ]
#    [0.31764707]
#    [0.23137255]]
#
#   [[0.827451  ]
#    [0.8156863 ]
#    [0.76862746]
#    ...
#    [0.34901962]
#    [0.27450982]
#    [0.3882353 ]]
#
#   ...
#
#   [[0.5568628 ]
#    [0.42352942]
#    [0.40392157]
#    ...
#    [0.6       ]
#    [0.5529412 ]
#    [0.5411765 ]]
#
#   [[0.4117647 ]
#    [0.32156864]
#    [0.2627451 ]
#    ...
#    [0.6       ]
#    [0.5294118 ]
#    [0.5529412 ]]
#
#   [[0.4392157 ]
#    [0.31764707]
#    [0.2784314 ]
#    ...
#    [0.5372549 ]
#    [0.5372549 ]
#    [0.72156864]]]
#
#
#  [[[0.7882353 ]
#    [0.7607843 ]
#    [0.6862745 ]
#    ...
#    [0.33333334]
#    [0.29803923]
#    [0.29803923]]
#
#   [[0.7176471 ]
#    [0.6745098 ]
#    [0.6431373 ]
#    ...
#    [0.50980395]
#    [0.31764707]
#    [0.1882353 ]]
#
#   [[0.62352943]
#    [0.6156863 ]
#    [0.67058825]
#    ...
#    [0.57254905]
#    [0.3647059 ]
#    [0.2509804 ]]
#
#   ...
#
#   [[0.6509804 ]
#    [0.5058824 ]
#    [0.36078432]
#    ...
#    [0.40784314]
#    [0.34117648]
#    [0.38431373]]
#
#   [[0.54901963]
#    [0.4117647 ]
#    [0.3254902 ]
#    ...
#    [0.42352942]
#    [0.31764707]
#    [0.3529412 ]]
#
#   [[0.42745098]
#    [0.34509805]
#    [0.3137255 ]
#    ...
#    [0.4509804 ]
#    [0.4       ]
#    [0.39607844]]]
#
#
#  [[[0.49411765]
#    [0.41960785]
#    [0.47843137]
#    ...
#    [0.6313726 ]
#    [0.6431373 ]
#    [0.69411767]]
#
#   [[0.5411765 ]
#    [0.4627451 ]
#    [0.48235294]
#    ...
#    [0.6       ]
#    [0.58431375]
#    [0.6       ]]
#
#   [[0.5529412 ]
#    [0.5294118 ]
#    [0.5686275 ]
#    ...
#    [0.5647059 ]
#    [0.5686275 ]
#    [0.5372549 ]]
#
#   ...
#
#   [[0.60784316]
#    [0.58431375]
#    [0.65882355]
#    ...
#    [0.54509807]
#    [0.4509804 ]
#    [0.47058824]]
#
#   [[0.6392157 ]
#    [0.6039216 ]
#    [0.6509804 ]
#    ...
#    [0.61960787]
#    [0.5529412 ]
#    [0.5803922 ]]
#
#   [[0.5921569 ]
#    [0.5529412 ]
#    [0.627451  ]
#    ...
#    [0.7176471 ]
#    [0.6431373 ]
#    [0.67058825]]]
#
#
#  [[[0.3254902 ]
#    [0.26666668]
#    [0.2509804 ]
#    ...
#    [0.24705882]
#    [0.21568628]
#    [0.29803923]]
#
#   [[0.36078432]
#    [0.18431373]
#    [0.19215687]
#    ...
#    [0.26666668]
#    [0.4117647 ]
#    [0.33333334]]
#
#   [[0.45490196]
#    [0.39607844]
#    [0.41568628]
#    ...
#    [0.2627451 ]
#    [0.36862746]
#    [0.42352942]]
#
#   ...
#
#   [[0.61960787]
#    [0.45490196]
#    [0.40784314]
#    ...
#    [0.54509807]
#    [0.2       ]
#    [0.24705882]]
#
#   [[0.52156866]
#    [0.39215687]
#    [0.39607844]
#    ...
#    [0.5882353 ]
#    [0.53333336]
#    [0.3254902 ]]
#
#   [[0.29411766]
#    [0.28627452]
#    [0.28627452]
#    ...
#    [0.57254905]
#    [0.6313726 ]
#    [0.4       ]]]]

# %% [markdown]
# <font color=#ff12f3 size="4.5" face="Arial"><b>4️⃣ Deep Residual U-Net Architectur</b></font>
#
# The ResUNet consists of three parts:<br/>
# `Encoding`<br/>
# `Bridge`<br/>
# `Decoding`<br/>
# In encoding units, instead of using pooling operation to downsample feature map size, a stride of 2 is applied to the first convolution block to reduce the feature map by half.<br/>
# Before each decoding unit, there is an up-sampling of feature maps from lower level and a concatenation with the feature maps from the corresponding encoding path.<br/>
# At last a 1x1 Convolution is applied with Sigmoid activation to obtain a desired segmentation map.<br/>
#
# ![ResUNet.png](attachment:ResUNet.png)

# %%
def resunet_model(
    img_height: int,
    img_width: int,
    img_channels: int,
    base_filters: int = 16,
    strides: tuple = 1,
    kernel_size: tuple = (3, 3),
    shortcut_kernel_size: tuple = (1, 1),
    use_batchnorm: bool = True,
    n_class: int = 1):
    """
    Create a ResUNet model with residual connections.

    Args:
        img_height: Height of input images
        img_width: Width of input images
        img_channels: Number of input channels
        base_filters: Number of filters in first conv layer
        stride: Stride for main convolutions
        kernel_size: Size of main convolution kernels
        shortcut_stride: Stride for shortcut convolutions
        shortcut_kernel_size: Size of shortcut convolution kernels
        transpose_kernel_size: Size of transpose convolution kernels
        use_batchnorm: Whether to use batch normalization
        dropout_rates: Dictionary of dropout rates for different depths
        n_class: Number of output classes

    Returns:
        A Keras Model instance
    """
    # Clear the TensorFlow session to free up memory and avoid conflicts
    # from previous model definitions
    tf.keras.backend.clear_session()
    
    # Input layer and normalization
    inputs = Input((img_height, img_width, img_channels))

    # Lambda layer to check max value and normalize only if > 1
    def normalize_inputs(x):
        max_val = tf.reduce_max(x)
        return tf.cond(tf.greater(max_val, 1.0), lambda: x / 255.0, lambda: x)

    inputs = Lambda(normalize_inputs, output_shape=(img_height, img_width, img_channels))(inputs)

    c1 = Conv2D(base_filters, kernel_size=kernel_size, strides=strides, padding='same', kernel_initializer='he_normal')(inputs)
    if use_batchnorm: c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    c1 = Conv2D(base_filters, kernel_size=kernel_size, strides=strides, padding='same', kernel_initializer='he_normal')(c1)

    shortcut = Conv2D(base_filters, kernel_size=shortcut_kernel_size, strides=strides, padding='same', kernel_initializer='he_normal')(inputs)
    if use_batchnorm: shortcut = BatchNormalization()(shortcut)
    out1 = Add()([c1, shortcut])

    # ======================================= ENCODER (Contracting Path) =======================================
    # Block 2
    if use_batchnorm: out1 = BatchNormalization()(out1)
    res1 = Activation('relu')(out1)
    res1 = Conv2D(base_filters * 2, kernel_size=kernel_size, padding='same', strides=2 * strides)(res1)
    if use_batchnorm: res1 = BatchNormalization()(res1)
    res1 = Activation('relu')(res1)
    res1 = Conv2D(base_filters * 2, kernel_size=kernel_size, padding='same', strides=1)(res1)
    shortcut1 = Conv2D(base_filters * 2, kernel_size=shortcut_kernel_size, padding='same', strides=2 * strides)(out1)
    if use_batchnorm: shortcut1 = BatchNormalization()(shortcut1)
    out2 = Add()([shortcut1, res1])

    # Block 3
    if use_batchnorm: out2 = BatchNormalization()(out2)
    res2 = Activation('relu')(out2)
    res2 = Conv2D(base_filters * 4, kernel_size=kernel_size, padding='same', strides=2 * strides)(res2)
    if use_batchnorm: res2 = BatchNormalization()(res2)
    res2 = Activation('relu')(res2)
    res2 = Conv2D(base_filters * 4, kernel_size=kernel_size, padding='same', strides=1)(res2)
    shortcut2 = Conv2D(base_filters * 4, kernel_size=shortcut_kernel_size, padding='same', strides=2 * strides)(out2)
    if use_batchnorm: shortcut2 = BatchNormalization()(shortcut2)
    out3 = Add()([shortcut2, res2])

    # Block 4
    if use_batchnorm: out3 = BatchNormalization()(out3)
    res3 = Activation('relu')(out3)
    res3 = Conv2D(base_filters * 8, kernel_size=kernel_size, padding='same', strides=2 * strides)(res3)
    if use_batchnorm: res3 = BatchNormalization()(res3)
    res3 = Activation('relu')(res3)
    res3 = Conv2D(base_filters * 8, kernel_size=kernel_size, padding='same', strides=1)(res3)
    shortcut3 = Conv2D(base_filters * 8, kernel_size=shortcut_kernel_size, padding='same', strides=2 * strides)(out3)
    if use_batchnorm: shortcut3 = BatchNormalization()(shortcut3)
    out4 = Add()([shortcut3, res3])

    # Block 5
    if use_batchnorm: out4 = BatchNormalization()(out4)
    res4 = Activation('relu')(out4)
    res4 = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=2 * strides)(res4)
    if use_batchnorm: res4 = BatchNormalization()(res4)
    res4 = Activation('relu')(res4)
    res4 = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=1)(res4)
    shortcut4 = Conv2D(base_filters*16, kernel_size=shortcut_kernel_size, padding='same', strides=2 * strides)(out4)
    if use_batchnorm: shortcut4 = BatchNormalization()(shortcut4)
    out5 = Add()([shortcut4, res4])

    # ========================================== BOTTLENECK (Bridge) ===========================================
    if use_batchnorm: out5 = BatchNormalization()(out5)
    conv = Activation('relu')(out5)
    conv = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=strides)(conv)
    if use_batchnorm: conv = BatchNormalization()(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=strides)(conv)

    # ======================================== DECODER (Expansive Path) ========================================
    # Upsample and concatenate with corresponding encoder features
    uconv1 = UpSampling2D((2, 2))(conv)
    uconv1 = concatenate([uconv1, out4])

    if use_batchnorm: uconv1 = BatchNormalization()(uconv1)
    uconv11 = Activation('relu')(uconv1)
    uconv11 = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=strides)(uconv11)
    if use_batchnorm: uconv11 = BatchNormalization()(uconv11)
    uconv11 = Activation('relu')(uconv11)
    uconv11 = Conv2D(base_filters * 16, kernel_size=kernel_size, padding='same', strides=1)(uconv11)
    shortcut5 = Conv2D(base_filters * 16, kernel_size=shortcut_kernel_size, padding='same', strides=strides)(uconv1)
    if use_batchnorm: shortcut5 = BatchNormalization()(shortcut5)
    out6 = Add()([uconv11, shortcut5])

    uconv2 = UpSampling2D((2, 2))(out6)
    uconv2 = concatenate([uconv2, out3])

    if use_batchnorm: uconv2 = BatchNormalization()(uconv2)
    uconv22 = Activation('relu')(uconv2)
    uconv22 = Conv2D(base_filters*8, kernel_size=kernel_size, padding='same', strides=strides)(uconv22)
    if use_batchnorm: uconv22 = BatchNormalization()(uconv22)
    uconv22 = Activation('relu')(uconv22)
    uconv22 = Conv2D(base_filters*8, kernel_size=kernel_size, padding='same', strides=1)(uconv22)
    shortcut6 = Conv2D(base_filters*8, kernel_size=shortcut_kernel_size, padding='same', strides=strides)(uconv2)
    if use_batchnorm: shortcut6 = BatchNormalization()(shortcut6)
    out7 = Add()([uconv22, shortcut6])

    uconv3 = UpSampling2D((2, 2))(out7)
    uconv3 = concatenate([uconv3, out2])

    if use_batchnorm: uconv3 = BatchNormalization()(uconv3)
    uconv33 = Activation('relu')(uconv3)
    uconv33 = Conv2D(base_filters*4, kernel_size=kernel_size, padding='same', strides=strides)(uconv33)
    if use_batchnorm: uconv33 = BatchNormalization()(uconv33)
    uconv33 = Activation('relu')(uconv33)
    uconv33 = Conv2D(base_filters*4, kernel_size=kernel_size, padding='same', strides=1)(uconv33)
    shortcut7 = Conv2D(base_filters*4, kernel_size=shortcut_kernel_size, padding='same', strides=strides)(uconv3)
    if use_batchnorm: shortcut7 = BatchNormalization()(shortcut7)
    out8 = Add()([uconv33, shortcut7])

    uconv4 = UpSampling2D((2, 2))(out8)
    uconv4 = concatenate([uconv4, out1])

    if use_batchnorm: uconv4 = BatchNormalization()(uconv4)
    uconv44 = Activation('relu')(uconv4)
    uconv44 = Conv2D(base_filters*2, kernel_size=kernel_size, padding='same', strides=strides)(uconv44)
    if use_batchnorm: uconv44 = BatchNormalization()(uconv44)
    uconv44 = Activation('relu')(uconv44)
    uconv44 = Conv2D(base_filters*2, kernel_size=kernel_size, padding='same', strides=1)(uconv44)
    shortcut8 = Conv2D(base_filters*2, kernel_size=shortcut_kernel_size, padding='same', strides=strides)(uconv4)
    if use_batchnorm: shortcut8 = BatchNormalization()(shortcut8)
    out9 = Add()([uconv44, shortcut8])

    # Output layer
    if n_class < 1: raise ValueError("Number of classes must be at least 1")
    act = 'sigmoid' if n_class == 1 else 'softmax'
    output_layer = Conv2D(n_class, (1, 1), padding="same", activation=act)(out9)

    model = Model(inputs, output_layer)

    return model

# %%
# Convert any tf.placeholder usage to tf.compat.v1.placeholder
tf.placeholder = tf.compat.v1.placeholder if hasattr(tf, 'placeholder') else None

img_height, img_width, img_channels = list(train_dataset.element_spec[0].shape[1:])

model = resunet_model(img_height,
                   img_width,
                   img_channels,
                   base_filters=16,
                  )
# model.summary()

# %% [markdown]
# <font color=#08d8f3 size="4.5" face="Arial"><b>5️⃣ Segmentation Metrics</b></font><br/>
# The selection of the appropriate loss function and metrics for the U-Net model depends on the specifics of the segmentation project (such as binary or multi-class), the characteristics of your dataset (like class imbalance), and your objectives (for instance, prioritizing precision or recall).
#
# **Loss Functions:**<br/>
# ▪ `binary_crossentropy:` Standard loss for binary classification/segmentation (pixel-wise 0 or 1).<br/>
# ▪ `metrics['dice_coef_loss']:` 1 - Dice coefficient, emphasizes overlap between predicted and true regions.<br/>
# ▪ `metrics['iou_coef_loss']:` 1 - IoU, focuses on intersection over union.<br/>
# ▪ `metrics['combined_loss']:` Combined BCE + Dice loss; Lower is better.<br/>
# ▪ `sparse_categorical_crossentropy:` For multi-class segmentation with integer labels (not one-hot encoded).<br/>
#
# **Metrics:**<br/>
# ▪ `accuracy:` Proportion of correctly classified pixels (can be misleading for imbalanced data).<br/>
# ▪ `metrics['dice_coef']:` Measures overlap (2 * intersection / union), ranges from 0 to 1.<br/>
# ▪ `metrics['iou']:` Intersection over union, ranges from 0 to 1.<br/>
# ▪ `Recall(): `True positives / (true positives + false negatives), good for detecting all positives.<br/>
# ▪ `Precision():` True positives / (true positives + false positives), good for reducing false positives.<br/>
#
# 🔹 `Dice loss` optimizes the overlap between predicted and true masks, making it crucial for segmentation tasks. It's especially effective for imbalanced datasets, like detecting small tumors in medical imaging, where binary cross-entropy may focus too much on the dominant background class.<br/>
# 🔹 `Binary cross-entropy` is a simpler and effective choice for pixel-wise classification when the dataset is well-balanced and predictions are confident. However, it is less robust to class imbalances compared to Dice or IoU losses.<br/>
# 🔹 Use `iou_coef_loss `when the task emphasizes precise region overlap instead of boundary smoothness, such as in object detection-like segmentation. IoU loss serves as an effective alternative to Dice, as it penalizes false positives and negatives differently.<br/>
# 🔹 The combination of `binary_crossentropy`, which provides pixel-level guidance, and `dice_coef_loss`, which focuses on overall overlap, helps balance local detail with structural fidelity. An initial alpha value of 0.5 is recommended, with adjustments made according to validation results.<br/>

# %%
def segmentation_metrics(alpha: float = 0.5):
    """
    Creates and returns a collection of metrics and loss functions specifically designed for image segmentation tasks.
    Includes implementations of:
    - Dice coefficient (F1 score for segmentation)
    - Dice loss (1 - Dice coefficient)
    - Intersection over Union (IoU/Jaccard index)
    - IoU loss (1 - IoU)
    - Combined loss (binary crossentropy + Dice loss)

    All functions are decorated with @tf.function for optimized TensorFlow graph execution and include numerical
    stability smoothing (epsilon value).

    Args:
    - alpha (float): Weighting factor between BCE and Dice loss in the combined loss.

    Returns:
    - dict: A dictionary containing metric/loss functions:
      - 'dice_coef': Dice coefficient metric; Higher is better (range 0-1)
      - 'dice_coef_loss': Dice loss function; Lower is better (range 0-1)
      - 'iou': IoU metric; Higher is better (range 0-1)
      - 'iou_coef_loss': IoU loss function; Lower is better (range 0-1)
      - 'combined_loss': Combined BCE + Dice loss; Lower is better

    Example:
    - adam = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False) # Or 'adam', 'rmsprop'
    - loss=metrics['combined_loss'], # Or binary_crossentropy, 'sparse_categorical_crossentropy', metrics['dice_coef_loss'], 'iou_coef_loss', 'combined_loss',
    - metrics = segmentation_metrics(labels=train_masks, alpha=0.2)
    - model.compile(optimizer=adam, loss=metrics['combined_loss'], metrics=['accuracy',
        metrics['dice_coef'], metrics['iou'], tf.keras.metrics.Recall(), tf.keras.metrics.Precision()],
        run_eagerly=False),  # Set run_eagerly=False for better performance
    """
    # Small constant to prevent division by zero and ensure numerical stability
    smooth = 1e-15

    @tf.function(reduce_retracing=True)
    def dice_coef(y_true, y_pred):
        """
        Computes the Dice coefficient (F1 score) between ground truth and predicted masks.

        The Dice coefficient measures the overlap between two samples, with values ranging
        from 0 (no overlap) to 1 (perfect overlap). Defined as:
        Dice = (2 * |X ∩ Y|) / (|X| + |Y|)

        Args:
        - y_true: Ground truth masks (tensor of shape [batch_size, height, width, channels])
        - y_pred: Predicted probability masks (tensor of same shape as y_true)

        Returns:
            Tensor: Scalar Dice coefficient value
        """
        # Ensure tensors are float32 for consistent computation
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Compute intersection (element-wise multiplication followed by sum)
        intersection = tf.reduce_sum(y_true * y_pred)
        # Compute union (sum of individual masks)
        union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
        # Calculate Dice coefficient with smoothing factor
        return (2. * intersection + smooth) / (union + smooth)

    @tf.function(reduce_retracing=True)
    def dice_coef_loss(y_true, y_pred):
        """
        Computes Dice loss as 1 - Dice coefficient.

        This loss function is commonly used in segmentation tasks where the target
        is to maximize the Dice coefficient. The loss ranges from 0 (perfect match)
        to 1 (no overlap).

        Args:
        - y_true: Ground truth masks (tensor)
        - y_pred: Predicted masks (tensor)

        Returns:
            Tensor: Scalar Dice loss value
        """
        return 1.0 - dice_coef(y_true, y_pred)

    @tf.function(reduce_retracing=True)
    def iou(y_true, y_pred):
        """
        Computes Intersection over Union (IoU/Jaccard index) between masks.

        IoU measures the overlap between two samples, with values ranging from
        0 (no overlap) to 1 (perfect overlap). Defined as:
        IoU = |X ∩ Y| / |X ∪ Y|

        Args:
        - y_true: Ground truth masks (tensor)
        - y_pred: Predicted masks (tensor)

        Returns:
            Tensor: Scalar IoU value
        """
        # Ensure tensors are float32 for consistent computation
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Compute intersection
        intersection = tf.reduce_sum(y_true * y_pred)
        # Compute total area covered by both masks
        total = tf.reduce_sum(y_true + y_pred)
        # Compute union (total area minus intersection)
        union = total - intersection
        # Calculate IoU with smoothing factor
        return (intersection + smooth) / (union + smooth)

    @tf.function(reduce_retracing=True)
    def iou_coef_loss(y_true, y_pred):
        """
        Computes IoU loss as 1 - IoU.

        This loss function is used in segmentation tasks where the target is to
        maximize the IoU metric. The loss ranges from 0 (perfect match) to 1
        (no overlap).

        Args:
        - y_true: Ground truth masks (tensor)
        - y_pred: Predicted masks (tensor)

        Returns:
            Tensor: Scalar IoU loss value
        """
        return 1.0 - iou(y_true, y_pred)

    @tf.function(reduce_retracing=True)
    def combined_loss(y_true, y_pred):
        """
        Computes a combined loss of binary crossentropy and Dice loss.

        This hybrid loss balances pixel-wise classification (BCE) with region overlap (Dice).
        The weighting factor alpha controls the contribution of each component:
        - Loss = alpha * BCE + (1 - alpha) * Dice_loss

        Args:
        - y_true: Ground truth masks (tensor)
        - y_pred: Predicted masks (tensor)
        - alpha: Weighting factor between BCE and Dice loss (default: 0.5)

        Returns:
            Tensor: Scalar combined loss value
        """
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        dice = dice_coef_loss(y_true, y_pred)
        return alpha * bce + (1 - alpha) * dice

    # Return all functions in a dictionary for easy access
    return {
        'dice_coef': dice_coef,            # Metric: Higher is better (range 0-1)
        'dice_coef_loss': dice_coef_loss,  # Loss: Lower is better (range 0-1)
        'iou': iou,                        # Metric: Higher is better (range 0-1)
        'iou_coef_loss': iou_coef_loss,    # Loss: Lower is better (range 0-1)
        'combined_loss': combined_loss,    # Loss: Lower is better
    }

# %%
metrics = segmentation_metrics(alpha=0.1)

adam = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-7, amsgrad=False)

# Compile the model with custom loss and metrics
model.compile(
    optimizer=adam,               # Or 'adam', 'rmsprop'
    loss='binary_crossentropy', # Or binary_crossentropy, 'sparse_categorical_crossentropy', metrics['dice_coef_loss'], 'iou_coef_loss', 'combined_loss'
    metrics=[
        'accuracy',
        metrics['dice_coef'],
        metrics['iou'],
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.Precision(name='precision'),
        ],
    run_eagerly=False,  # Set run_eagerly=False for better performance
    )

# %% [markdown]
# <font color=#ffbb54 size="4.5" face="Arial"><b>6️⃣ Callbacks</b></font><br/>
# `EarlyStopping`<br/>
# ▪ Stops training if `val_loss` doesn’t improve for 5 epochs.<br/>
# ▪ Keeps final weights (not best) when stopping.<br/>
# ▪ Prevents overfitting, saves time.<br/>
#
# `CSVLogger(csv_path)`<br/>
# ▪ Logs all metrics (e.g., loss, accuracy) to a CSV file each epoch.<br/>
# ▪ Creates a persistent record for analysis.<br/>
# ▪ Track progress, analyze later.<br/>
#
# `ModelCheckpoint`<br/>
# ▪ Saves the model to a file when `val_loss` improves.<br/>
# ▪ Only saves the best model (overwrites previous saves).<br/>
# ▪ Preserves the best model state.<br/>
#
# `ReduceLROnPlateau`<br/>
# ▪ Reduces learning rate by 10x (e.g., 1e-4 to 1e-5) if `val_loss` stalls for 5 epochs.<br/>
# ▪ Won’t go below 1e-7; prints updates.<br/>
# ▪ Helps fine-tune when training plateaus.<br/>

# %%
class ShowImageTrainingProgress(keras.callbacks.Callback):
    """
    Custom callback to display input image, ground truth mask, predicted mask,
    and training loss plot at the end of training or when training stops early.

    Example:
    - callbacks = [ShowImageTrainingProgress(train_dataset, sample_idx=0)]
    """

    def __init__(self, dataset, sample_idx=0, figsize=(8, 3.5)):
        """
        Args:
            dataset: tf.data.Dataset object containing (image, mask) pairs
            sample_idx: Index of the sample to display from the dataset (default: 0)
            figsize: Figure size for the display (default: (8, 3.5))
        """
        super().__init__()
        self.dataset = dataset
        self.sample_idx = sample_idx
        self.figsize = figsize
        self.images = None
        self.masks = None
        self.predictions = {}  # Store predictions for first and last epochs
        self.epochs_trained = 0

    def on_train_begin(self, logs=None):
        """Initialize at the start of training."""
        self.predictions.clear()
        self.epochs_trained = 0

    def on_epoch_begin(self, epoch, logs=None):
        """Capture prediction at the start of the first epoch."""
        if epoch == 0:
            self._store_images_and_predictions(epoch)

    def on_epoch_end(self, epoch, logs=None):
        """Store loss and predictions, increment epoch count."""
        self.epochs_trained = epoch + 1
        # Store prediction for the current epoch
        self._store_images_and_predictions(epoch)

    def on_train_end(self, logs=None):
        """Display images and loss plot when training ends."""
        self._display_images_and_loss()

    def _store_images_and_predictions(self, epoch):
        """Store the input image, ground truth mask, and predicted mask for the specified epoch."""
        for batch in self.dataset.take(1):
            images, masks = batch
            self.images = images[self.sample_idx].numpy()
            self.masks = masks[self.sample_idx].numpy()
            pred = self.model.predict(np.expand_dims(self.images, axis=0), verbose=0)[0]
            self.predictions[epoch] = pred

    def _display_images_and_loss(self):
        """Display input image, ground truth mask, predicted masks, and loss plot."""
        fig = plt.figure(figsize=self.figsize)

        # Input Image
        plt.subplot(1, 4, 1)
        plt.imshow(self.images)
        plt.title("Input Image", fontsize=10)
        plt.axis('off')

        # Ground Truth Mask
        plt.subplot(1, 4, 2)
        plt.imshow(np.squeeze(self.masks), cmap='gray')
        plt.title("Ground Truth Mask", fontsize=10)
        plt.axis('off')

        # Predicted Mask at First Epoch
        plt.subplot(1, 4, 3)
        plt.imshow(np.squeeze(self.predictions[0]), cmap='gray')
        plt.title("Predicted Mask. Epoch 1", fontsize=10)
        plt.axis('off')

        # Predicted Mask at Last Epoch
        last_epoch = min(self.epochs_trained - 1, max(self.predictions.keys()))
        plt.subplot(1, 4, 4)
        plt.imshow(np.squeeze(self.predictions[last_epoch]), cmap='gray')
        plt.title(f"Predicted Mask. Epoch {last_epoch + 1}", fontsize=10)
        plt.axis('off')

        plt.tight_layout()
        plt.show()

# %%
# csv_path = os.path.join("files", "log.csv")
csv_path = 'training_log_Membrance_resunet.csv'  # File to log training metrics for UNet model
model_checkpoint_path = 'Membrance_resunet_model.keras'  # File to save the best UNet model

callbacks = [
    CSVLogger(csv_path),  # Logs metrics to a CSV file
    ShowImageTrainingProgress(train_dataset, sample_idx=0, figsize=(8, 3.5)),  # Show the first sample in the batch
    ModelCheckpoint(
        filepath=model_checkpoint_path,
        monitor='val_loss',   # Monitor validation loss
        verbose=1,            # Print when saving
        save_best_only=True   # Save only when val_loss improves
    ),
    ReduceLROnPlateau(
        monitor='val_loss',   # Monitor validation loss
        factor=0.1,           # Reduce learning rate by 10x
        patience=10,          # Wait 5 epochs without improvement
        min_lr=1e-6,          # Minimum learning rate
        verbose=1             # Print when reducing LR
    ),
    EarlyStopping(
        monitor='val_loss',         # Monitor validation loss
        patience=10,                # Stop after 5 epochs without improvement
        restore_best_weights=True   # Restore best weights (changed to True for better results)
    )
]

# %% [markdown]
# <font color=#0f6d17 size="4.5" face="Arial"><b>7️⃣ Training the model</b></font><br/>

# %%
# Hyperparameters
num_epochs = 100
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    callbacks=callbacks,
    validation_data=valid_dataset,
    shuffle=False,
    verbose=1,
)

# Evaluate on test set
results = model.evaluate(test_dataset, return_dict=True, verbose=1)
# print(f"Test Dice Coefficient: {results['dice_coef']:.3f}")
# print(f"Test IoU: {results['iou']:.3f}")
# print(f"Test Recall: {results['recall']:.3f}")
# print(f"Test Precision: {results['precision']:.3f}")
# print(f"Test Loss: {results['loss']:.3f}")
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6479 - dice_coef: 0.7183 - iou: 0.5695 - loss: 0.7290 - precision: 0.8476 - recall: 0.6667
# Epoch 1: val_loss improved from inf to 16.28717, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - accuracy: 0.6598 - dice_coef: 0.7290 - iou: 0.5831 - loss: 0.7081 - precision: 0.8498 - recall: 0.6829 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 16.2872 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8430 - dice_coef: 0.8720 - iou: 0.7733 - loss: 0.3420 - precision: 0.8903 - recall: 0.9113
# Epoch 2: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 337ms/step - accuracy: 0.8449 - dice_coef: 0.8733 - iou: 0.7754 - loss: 0.3384 - precision: 0.8905 - recall: 0.9136 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 26.7566 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8758 - dice_coef: 0.8903 - iou: 0.8023 - loss: 0.2771 - precision: 0.9185 - recall: 0.9232
# Epoch 3: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.8760 - dice_coef: 0.8908 - iou: 0.8031 - loss: 0.2769 - precision: 0.9182 - recall: 0.9236 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 61.5422 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.8865 - dice_coef: 0.8982 - iou: 0.8153 - loss: 0.2607 - precision: 0.9171 - recall: 0.9389
# Epoch 4: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.8871 - dice_coef: 0.8986 - iou: 0.8158 - loss: 0.2594 - precision: 0.9183 - recall: 0.9383 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 55.2059 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.8945 - dice_coef: 0.9032 - iou: 0.8236 - loss: 0.2422 - precision: 0.9251 - recall: 0.9408
# Epoch 5: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.8950 - dice_coef: 0.9036 - iou: 0.8242 - loss: 0.2414 - precision: 0.9250 - recall: 0.9414 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 106.2378 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9040 - dice_coef: 0.9123 - iou: 0.8387 - loss: 0.2211 - precision: 0.9394 - recall: 0.9369
# Epoch 6: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 327ms/step - accuracy: 0.9037 - dice_coef: 0.9122 - iou: 0.8385 - loss: 0.2217 - precision: 0.9397 - recall: 0.9361 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 41.3550 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9032 - dice_coef: 0.9137 - iou: 0.8411 - loss: 0.2221 - precision: 0.9202 - recall: 0.9590
# Epoch 7: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 331ms/step - accuracy: 0.9035 - dice_coef: 0.9138 - iou: 0.8413 - loss: 0.2213 - precision: 0.9207 - recall: 0.9588 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 79.8109 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.9118 - dice_coef: 0.9188 - iou: 0.8497 - loss: 0.2023 - precision: 0.9477 - recall: 0.9390
# Epoch 8: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 341ms/step - accuracy: 0.9121 - dice_coef: 0.9189 - iou: 0.8499 - loss: 0.2017 - precision: 0.9478 - recall: 0.9393 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 26.8669 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9213 - dice_coef: 0.9246 - iou: 0.8598 - loss: 0.1844 - precision: 0.9501 - recall: 0.9491
# Epoch 9: val_loss did not improve from 16.28717
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 350ms/step - accuracy: 0.9213 - dice_coef: 0.9248 - iou: 0.8601 - loss: 0.1844 - precision: 0.9501 - recall: 0.9490 - val_accuracy: 0.7926 - val_dice_coef: 0.8843 - val_iou: 0.7926 - val_loss: 30.8762 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9256 - dice_coef: 0.9313 - iou: 0.8714 - loss: 0.1726 - precision: 0.9462 - recall: 0.9584
# Epoch 10: val_loss improved from 16.28717 to 10.41551, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.9256 - dice_coef: 0.9314 - iou: 0.8717 - loss: 0.1725 - precision: 0.9467 - recall: 0.9580 - val_accuracy: 0.7926 - val_dice_coef: 0.8842 - val_iou: 0.7925 - val_loss: 10.4155 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.9303 - dice_coef: 0.9352 - iou: 0.8783 - loss: 0.1631 - precision: 0.9490 - recall: 0.9622
# Epoch 11: val_loss did not improve from 10.41551
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.9302 - dice_coef: 0.9349 - iou: 0.8777 - loss: 0.1634 - precision: 0.9489 - recall: 0.9622 - val_accuracy: 0.7926 - val_dice_coef: 0.8842 - val_iou: 0.7925 - val_loss: 11.6975 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9303 - dice_coef: 0.9327 - iou: 0.8740 - loss: 0.1617 - precision: 0.9662 - recall: 0.9432
# Epoch 12: val_loss improved from 10.41551 to 4.82225, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 502ms/step - accuracy: 0.9300 - dice_coef: 0.9324 - iou: 0.8733 - loss: 0.1623 - precision: 0.9662 - recall: 0.9429 - val_accuracy: 0.7926 - val_dice_coef: 0.8840 - val_iou: 0.7921 - val_loss: 4.8222 - val_precision: 0.7928 - val_recall: 0.9995 - learning_rate: 0.0010
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9314 - dice_coef: 0.9364 - iou: 0.8804 - loss: 0.1591 - precision: 0.9514 - recall: 0.9609
# Epoch 13: val_loss did not improve from 4.82225
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - accuracy: 0.9314 - dice_coef: 0.9363 - iou: 0.8802 - loss: 0.1590 - precision: 0.9516 - recall: 0.9607 - val_accuracy: 0.7926 - val_dice_coef: 0.8842 - val_iou: 0.7925 - val_loss: 9.9227 - val_precision: 0.7926 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9341 - dice_coef: 0.9374 - iou: 0.8823 - loss: 0.1532 - precision: 0.9631 - recall: 0.9513
# Epoch 14: val_loss did not improve from 4.82225
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - accuracy: 0.9342 - dice_coef: 0.9378 - iou: 0.8828 - loss: 0.1529 - precision: 0.9634 - recall: 0.9512 - val_accuracy: 0.7926 - val_dice_coef: 0.8840 - val_iou: 0.7921 - val_loss: 4.8835 - val_precision: 0.7926 - val_recall: 0.9999 - learning_rate: 0.0010
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9396 - dice_coef: 0.9438 - iou: 0.8936 - loss: 0.1412 - precision: 0.9592 - recall: 0.9637
# Epoch 15: val_loss did not improve from 4.82225
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.9396 - dice_coef: 0.9440 - iou: 0.8939 - loss: 0.1412 - precision: 0.9591 - recall: 0.9637 - val_accuracy: 0.7925 - val_dice_coef: 0.8841 - val_iou: 0.7923 - val_loss: 5.7148 - val_precision: 0.7926 - val_recall: 0.9998 - learning_rate: 0.0010
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9415 - dice_coef: 0.9448 - iou: 0.8954 - loss: 0.1359 - precision: 0.9630 - recall: 0.9616
# Epoch 16: val_loss improved from 4.82225 to 3.41060, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 499ms/step - accuracy: 0.9418 - dice_coef: 0.9450 - iou: 0.8958 - loss: 0.1353 - precision: 0.9633 - recall: 0.9617 - val_accuracy: 0.7925 - val_dice_coef: 0.8839 - val_iou: 0.7920 - val_loss: 3.4106 - val_precision: 0.7927 - val_recall: 0.9996 - learning_rate: 0.0010
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9460 - dice_coef: 0.9507 - iou: 0.9060 - loss: 0.1252 - precision: 0.9688 - recall: 0.9622
# Epoch 17: val_loss improved from 3.41060 to 2.95686, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 497ms/step - accuracy: 0.9461 - dice_coef: 0.9507 - iou: 0.9060 - loss: 0.1251 - precision: 0.9686 - recall: 0.9623 - val_accuracy: 0.7927 - val_dice_coef: 0.8840 - val_iou: 0.7921 - val_loss: 2.9569 - val_precision: 0.7928 - val_recall: 0.9998 - learning_rate: 0.0010
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9502 - dice_coef: 0.9536 - iou: 0.9113 - loss: 0.1162 - precision: 0.9711 - recall: 0.9654
# Epoch 18: val_loss did not improve from 2.95686
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.9499 - dice_coef: 0.9532 - iou: 0.9106 - loss: 0.1170 - precision: 0.9702 - recall: 0.9657 - val_accuracy: 0.7925 - val_dice_coef: 0.8840 - val_iou: 0.7921 - val_loss: 2.9994 - val_precision: 0.7927 - val_recall: 0.9997 - learning_rate: 0.0010
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9513 - dice_coef: 0.9540 - iou: 0.9121 - loss: 0.1135 - precision: 0.9751 - recall: 0.9621
# Epoch 19: val_loss improved from 2.95686 to 2.42304, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.9512 - dice_coef: 0.9541 - iou: 0.9122 - loss: 0.1137 - precision: 0.9751 - recall: 0.9620 - val_accuracy: 0.7928 - val_dice_coef: 0.8839 - val_iou: 0.7920 - val_loss: 2.4230 - val_precision: 0.7930 - val_recall: 0.9994 - learning_rate: 0.0010
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9527 - dice_coef: 0.9569 - iou: 0.9173 - loss: 0.1101 - precision: 0.9676 - recall: 0.9724
# Epoch 20: val_loss improved from 2.42304 to 1.99650, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 648ms/step - accuracy: 0.9526 - dice_coef: 0.9567 - iou: 0.9170 - loss: 0.1104 - precision: 0.9673 - recall: 0.9724 - val_accuracy: 0.7928 - val_dice_coef: 0.8838 - val_iou: 0.7919 - val_loss: 1.9965 - val_precision: 0.7931 - val_recall: 0.9994 - learning_rate: 0.0010
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9535 - dice_coef: 0.9566 - iou: 0.9167 - loss: 0.1081 - precision: 0.9776 - recall: 0.9618
# Epoch 21: val_loss improved from 1.99650 to 1.58324, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 501ms/step - accuracy: 0.9535 - dice_coef: 0.9568 - iou: 0.9172 - loss: 0.1080 - precision: 0.9778 - recall: 0.9616 - val_accuracy: 0.7927 - val_dice_coef: 0.8837 - val_iou: 0.7917 - val_loss: 1.5832 - val_precision: 0.7931 - val_recall: 0.9992 - learning_rate: 0.0010
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9547 - dice_coef: 0.9589 - iou: 0.9210 - loss: 0.1052 - precision: 0.9638 - recall: 0.9786
# Epoch 22: val_loss did not improve from 1.58324
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.9547 - dice_coef: 0.9589 - iou: 0.9211 - loss: 0.1051 - precision: 0.9643 - recall: 0.9781 - val_accuracy: 0.7925 - val_dice_coef: 0.8839 - val_iou: 0.7921 - val_loss: 1.8582 - val_precision: 0.7929 - val_recall: 0.9992 - learning_rate: 0.0010
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9568 - dice_coef: 0.9591 - iou: 0.9215 - loss: 0.1001 - precision: 0.9770 - recall: 0.9670
# Epoch 23: val_loss did not improve from 1.58324
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.9569 - dice_coef: 0.9590 - iou: 0.9213 - loss: 0.1001 - precision: 0.9769 - recall: 0.9672 - val_accuracy: 0.7927 - val_dice_coef: 0.8840 - val_iou: 0.7922 - val_loss: 1.6181 - val_precision: 0.7930 - val_recall: 0.9992 - learning_rate: 0.0010
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9586 - dice_coef: 0.9617 - iou: 0.9262 - loss: 0.0965 - precision: 0.9762 - recall: 0.9707
# Epoch 24: val_loss did not improve from 1.58324
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 360ms/step - accuracy: 0.9587 - dice_coef: 0.9617 - iou: 0.9262 - loss: 0.0964 - precision: 0.9762 - recall: 0.9707 - val_accuracy: 0.7928 - val_dice_coef: 0.8840 - val_iou: 0.7922 - val_loss: 1.8447 - val_precision: 0.7932 - val_recall: 0.9991 - learning_rate: 0.0010
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9589 - dice_coef: 0.9611 - iou: 0.9251 - loss: 0.0959 - precision: 0.9765 - recall: 0.9705
# Epoch 25: val_loss improved from 1.58324 to 1.35879, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.9590 - dice_coef: 0.9613 - iou: 0.9254 - loss: 0.0957 - precision: 0.9765 - recall: 0.9707 - val_accuracy: 0.7938 - val_dice_coef: 0.8842 - val_iou: 0.7925 - val_loss: 1.3588 - val_precision: 0.7943 - val_recall: 0.9985 - learning_rate: 0.0010
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9621 - dice_coef: 0.9639 - iou: 0.9303 - loss: 0.0887 - precision: 0.9772 - recall: 0.9739
# Epoch 26: val_loss improved from 1.35879 to 1.30636, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - accuracy: 0.9621 - dice_coef: 0.9639 - iou: 0.9303 - loss: 0.0886 - precision: 0.9775 - recall: 0.9736 - val_accuracy: 0.7940 - val_dice_coef: 0.8844 - val_iou: 0.7928 - val_loss: 1.3064 - val_precision: 0.7947 - val_recall: 0.9978 - learning_rate: 0.0010
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9646 - dice_coef: 0.9659 - iou: 0.9341 - loss: 0.0836 - precision: 0.9769 - recall: 0.9775
# Epoch 27: val_loss improved from 1.30636 to 1.15970, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - accuracy: 0.9644 - dice_coef: 0.9658 - iou: 0.9339 - loss: 0.0839 - precision: 0.9770 - recall: 0.9773 - val_accuracy: 0.7940 - val_dice_coef: 0.8845 - val_iou: 0.7929 - val_loss: 1.1597 - val_precision: 0.7945 - val_recall: 0.9983 - learning_rate: 0.0010
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9630 - dice_coef: 0.9668 - iou: 0.9357 - loss: 0.0863 - precision: 0.9714 - recall: 0.9817
# Epoch 28: val_loss did not improve from 1.15970
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step - accuracy: 0.9630 - dice_coef: 0.9668 - iou: 0.9358 - loss: 0.0864 - precision: 0.9712 - recall: 0.9818 - val_accuracy: 0.7944 - val_dice_coef: 0.8847 - val_iou: 0.7932 - val_loss: 1.3572 - val_precision: 0.7952 - val_recall: 0.9974 - learning_rate: 0.0010
# Epoch 29/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9659 - dice_coef: 0.9668 - iou: 0.9357 - loss: 0.0803 - precision: 0.9841 - recall: 0.9719
# Epoch 29: val_loss did not improve from 1.15970
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 392ms/step - accuracy: 0.9656 - dice_coef: 0.9664 - iou: 0.9350 - loss: 0.0810 - precision: 0.9837 - recall: 0.9719 - val_accuracy: 0.7949 - val_dice_coef: 0.8850 - val_iou: 0.7938 - val_loss: 1.3465 - val_precision: 0.7956 - val_recall: 0.9975 - learning_rate: 0.0010
# Epoch 30/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9662 - dice_coef: 0.9677 - iou: 0.9374 - loss: 0.0797 - precision: 0.9801 - recall: 0.9764
# Epoch 30: val_loss did not improve from 1.15970
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.9662 - dice_coef: 0.9677 - iou: 0.9374 - loss: 0.0796 - precision: 0.9802 - recall: 0.9763 - val_accuracy: 0.7944 - val_dice_coef: 0.8850 - val_iou: 0.7937 - val_loss: 1.2716 - val_precision: 0.7950 - val_recall: 0.9980 - learning_rate: 0.0010
# Epoch 31/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9664 - dice_coef: 0.9690 - iou: 0.9398 - loss: 0.0789 - precision: 0.9783 - recall: 0.9788
# Epoch 31: val_loss did not improve from 1.15970
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step - accuracy: 0.9663 - dice_coef: 0.9690 - iou: 0.9399 - loss: 0.0790 - precision: 0.9780 - recall: 0.9790 - val_accuracy: 0.7957 - val_dice_coef: 0.8852 - val_iou: 0.7940 - val_loss: 1.2776 - val_precision: 0.7968 - val_recall: 0.9964 - learning_rate: 0.0010
# Epoch 32/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9688 - dice_coef: 0.9705 - iou: 0.9427 - loss: 0.0740 - precision: 0.9857 - recall: 0.9743
# Epoch 32: val_loss improved from 1.15970 to 1.12132, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 508ms/step - accuracy: 0.9688 - dice_coef: 0.9703 - iou: 0.9423 - loss: 0.0742 - precision: 0.9854 - recall: 0.9744 - val_accuracy: 0.7967 - val_dice_coef: 0.8858 - val_iou: 0.7951 - val_loss: 1.1213 - val_precision: 0.7975 - val_recall: 0.9966 - learning_rate: 0.0010
# Epoch 33/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9693 - dice_coef: 0.9713 - iou: 0.9443 - loss: 0.0723 - precision: 0.9796 - recall: 0.9813
# Epoch 33: val_loss did not improve from 1.12132
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - accuracy: 0.9692 - dice_coef: 0.9712 - iou: 0.9441 - loss: 0.0725 - precision: 0.9797 - recall: 0.9811 - val_accuracy: 0.7969 - val_dice_coef: 0.8859 - val_iou: 0.7952 - val_loss: 1.3121 - val_precision: 0.7977 - val_recall: 0.9965 - learning_rate: 0.0010
# Epoch 34/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9707 - dice_coef: 0.9726 - iou: 0.9466 - loss: 0.0690 - precision: 0.9843 - recall: 0.9780
# Epoch 34: val_loss did not improve from 1.12132
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 396ms/step - accuracy: 0.9707 - dice_coef: 0.9726 - iou: 0.9467 - loss: 0.0691 - precision: 0.9840 - recall: 0.9783 - val_accuracy: 0.7973 - val_dice_coef: 0.8862 - val_iou: 0.7957 - val_loss: 1.2635 - val_precision: 0.7978 - val_recall: 0.9968 - learning_rate: 0.0010
# Epoch 35/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9701 - dice_coef: 0.9720 - iou: 0.9456 - loss: 0.0705 - precision: 0.9835 - recall: 0.9780
# Epoch 35: val_loss did not improve from 1.12132
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 346ms/step - accuracy: 0.9701 - dice_coef: 0.9719 - iou: 0.9453 - loss: 0.0705 - precision: 0.9835 - recall: 0.9780 - val_accuracy: 0.7965 - val_dice_coef: 0.8858 - val_iou: 0.7951 - val_loss: 1.4244 - val_precision: 0.7970 - val_recall: 0.9972 - learning_rate: 0.0010
# Epoch 36/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9718 - dice_coef: 0.9722 - iou: 0.9458 - loss: 0.0671 - precision: 0.9837 - recall: 0.9796
# Epoch 36: val_loss improved from 1.12132 to 1.09866, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 538ms/step - accuracy: 0.9717 - dice_coef: 0.9722 - iou: 0.9460 - loss: 0.0672 - precision: 0.9840 - recall: 0.9793 - val_accuracy: 0.8015 - val_dice_coef: 0.8882 - val_iou: 0.7989 - val_loss: 1.0987 - val_precision: 0.8019 - val_recall: 0.9954 - learning_rate: 0.0010
# Epoch 37/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9700 - dice_coef: 0.9726 - iou: 0.9467 - loss: 0.0708 - precision: 0.9781 - recall: 0.9833
# Epoch 37: val_loss did not improve from 1.09866
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.9700 - dice_coef: 0.9727 - iou: 0.9469 - loss: 0.0706 - precision: 0.9784 - recall: 0.9832 - val_accuracy: 0.7962 - val_dice_coef: 0.8857 - val_iou: 0.7948 - val_loss: 1.3987 - val_precision: 0.7969 - val_recall: 0.9969 - learning_rate: 0.0010
# Epoch 38/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9706 - dice_coef: 0.9725 - iou: 0.9465 - loss: 0.0693 - precision: 0.9843 - recall: 0.9780
# Epoch 38: val_loss improved from 1.09866 to 1.08560, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 0.9706 - dice_coef: 0.9725 - iou: 0.9464 - loss: 0.0693 - precision: 0.9843 - recall: 0.9779 - val_accuracy: 0.7978 - val_dice_coef: 0.8867 - val_iou: 0.7965 - val_loss: 1.0856 - val_precision: 0.7982 - val_recall: 0.9969 - learning_rate: 0.0010
# Epoch 39/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9709 - dice_coef: 0.9728 - iou: 0.9470 - loss: 0.0684 - precision: 0.9749 - recall: 0.9880
# Epoch 39: val_loss did not improve from 1.08560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 358ms/step - accuracy: 0.9710 - dice_coef: 0.9728 - iou: 0.9471 - loss: 0.0681 - precision: 0.9751 - recall: 0.9880 - val_accuracy: 0.7982 - val_dice_coef: 0.8863 - val_iou: 0.7959 - val_loss: 1.2844 - val_precision: 0.7996 - val_recall: 0.9948 - learning_rate: 0.0010
# Epoch 40/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9704 - dice_coef: 0.9727 - iou: 0.9469 - loss: 0.0690 - precision: 0.9879 - recall: 0.9738
# Epoch 40: val_loss improved from 1.08560 to 1.03531, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - accuracy: 0.9706 - dice_coef: 0.9729 - iou: 0.9472 - loss: 0.0686 - precision: 0.9877 - recall: 0.9744 - val_accuracy: 0.8047 - val_dice_coef: 0.8893 - val_iou: 0.8006 - val_loss: 1.0353 - val_precision: 0.8057 - val_recall: 0.9930 - learning_rate: 0.0010
# Epoch 41/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9751 - dice_coef: 0.9758 - iou: 0.9528 - loss: 0.0594 - precision: 0.9839 - recall: 0.9840
# Epoch 41: val_loss did not improve from 1.03531
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.9749 - dice_coef: 0.9759 - iou: 0.9529 - loss: 0.0596 - precision: 0.9841 - recall: 0.9836 - val_accuracy: 0.8028 - val_dice_coef: 0.8883 - val_iou: 0.7990 - val_loss: 1.1054 - val_precision: 0.8047 - val_recall: 0.9919 - learning_rate: 0.0010
# Epoch 42/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9753 - dice_coef: 0.9772 - iou: 0.9553 - loss: 0.0584 - precision: 0.9827 - recall: 0.9860
# Epoch 42: val_loss did not improve from 1.03531
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step - accuracy: 0.9752 - dice_coef: 0.9772 - iou: 0.9553 - loss: 0.0586 - precision: 0.9822 - recall: 0.9863 - val_accuracy: 0.8005 - val_dice_coef: 0.8874 - val_iou: 0.7976 - val_loss: 1.2313 - val_precision: 0.8019 - val_recall: 0.9939 - learning_rate: 0.0010
# Epoch 43/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9749 - dice_coef: 0.9765 - iou: 0.9541 - loss: 0.0594 - precision: 0.9898 - recall: 0.9778
# Epoch 43: val_loss improved from 1.03531 to 0.97651, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 499ms/step - accuracy: 0.9750 - dice_coef: 0.9765 - iou: 0.9542 - loss: 0.0592 - precision: 0.9898 - recall: 0.9780 - val_accuracy: 0.8062 - val_dice_coef: 0.8903 - val_iou: 0.8022 - val_loss: 0.9765 - val_precision: 0.8072 - val_recall: 0.9924 - learning_rate: 0.0010
# Epoch 44/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9741 - dice_coef: 0.9764 - iou: 0.9539 - loss: 0.0611 - precision: 0.9767 - recall: 0.9904
# Epoch 44: val_loss did not improve from 0.97651
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 357ms/step - accuracy: 0.9741 - dice_coef: 0.9765 - iou: 0.9541 - loss: 0.0609 - precision: 0.9768 - recall: 0.9905 - val_accuracy: 0.8085 - val_dice_coef: 0.8909 - val_iou: 0.8033 - val_loss: 1.1133 - val_precision: 0.8118 - val_recall: 0.9872 - learning_rate: 0.0010
# Epoch 45/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9740 - dice_coef: 0.9762 - iou: 0.9535 - loss: 0.0613 - precision: 0.9914 - recall: 0.9752
# Epoch 45: val_loss improved from 0.97651 to 0.95289, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - accuracy: 0.9742 - dice_coef: 0.9762 - iou: 0.9535 - loss: 0.0609 - precision: 0.9912 - recall: 0.9757 - val_accuracy: 0.8141 - val_dice_coef: 0.8937 - val_iou: 0.8078 - val_loss: 0.9529 - val_precision: 0.8158 - val_recall: 0.9885 - learning_rate: 0.0010
# Epoch 46/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9769 - dice_coef: 0.9782 - iou: 0.9573 - loss: 0.0547 - precision: 0.9834 - recall: 0.9870
# Epoch 46: val_loss improved from 0.95289 to 0.92063, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.9768 - dice_coef: 0.9782 - iou: 0.9573 - loss: 0.0549 - precision: 0.9835 - recall: 0.9868 - val_accuracy: 0.8180 - val_dice_coef: 0.8957 - val_iou: 0.8112 - val_loss: 0.9206 - val_precision: 0.8190 - val_recall: 0.9889 - learning_rate: 0.0010
# Epoch 47/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9781 - dice_coef: 0.9787 - iou: 0.9582 - loss: 0.0525 - precision: 0.9885 - recall: 0.9832
# Epoch 47: val_loss did not improve from 0.92063
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 0.9780 - dice_coef: 0.9787 - iou: 0.9583 - loss: 0.0527 - precision: 0.9882 - recall: 0.9834 - val_accuracy: 0.8079 - val_dice_coef: 0.8912 - val_iou: 0.8038 - val_loss: 1.0602 - val_precision: 0.8088 - val_recall: 0.9922 - learning_rate: 0.0010
# Epoch 48/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9796 - dice_coef: 0.9796 - iou: 0.9600 - loss: 0.0493 - precision: 0.9873 - recall: 0.9864
# Epoch 48: val_loss did not improve from 0.92063
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 338ms/step - accuracy: 0.9794 - dice_coef: 0.9795 - iou: 0.9598 - loss: 0.0495 - precision: 0.9874 - recall: 0.9862 - val_accuracy: 0.8156 - val_dice_coef: 0.8945 - val_iou: 0.8092 - val_loss: 0.9611 - val_precision: 0.8172 - val_recall: 0.9883 - learning_rate: 0.0010
# Epoch 49/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9800 - dice_coef: 0.9802 - iou: 0.9612 - loss: 0.0481 - precision: 0.9871 - recall: 0.9871
# Epoch 49: val_loss improved from 0.92063 to 0.90704, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 613ms/step - accuracy: 0.9798 - dice_coef: 0.9801 - iou: 0.9609 - loss: 0.0483 - precision: 0.9869 - recall: 0.9872 - val_accuracy: 0.8238 - val_dice_coef: 0.8980 - val_iou: 0.8148 - val_loss: 0.9070 - val_precision: 0.8265 - val_recall: 0.9843 - learning_rate: 0.0010
# Epoch 50/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9800 - dice_coef: 0.9803 - iou: 0.9614 - loss: 0.0479 - precision: 0.9903 - recall: 0.9840
# Epoch 50: val_loss improved from 0.90704 to 0.82113, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.9798 - dice_coef: 0.9801 - iou: 0.9610 - loss: 0.0484 - precision: 0.9902 - recall: 0.9838 - val_accuracy: 0.8310 - val_dice_coef: 0.9012 - val_iou: 0.8202 - val_loss: 0.8211 - val_precision: 0.8340 - val_recall: 0.9822 - learning_rate: 0.0010
# Epoch 51/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9783 - dice_coef: 0.9800 - iou: 0.9607 - loss: 0.0511 - precision: 0.9841 - recall: 0.9880
# Epoch 51: val_loss did not improve from 0.82113
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 0.9782 - dice_coef: 0.9800 - iou: 0.9608 - loss: 0.0512 - precision: 0.9842 - recall: 0.9879 - val_accuracy: 0.8346 - val_dice_coef: 0.9025 - val_iou: 0.8224 - val_loss: 0.8395 - val_precision: 0.8397 - val_recall: 0.9780 - learning_rate: 0.0010
# Epoch 52/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9800 - dice_coef: 0.9800 - iou: 0.9609 - loss: 0.0480 - precision: 0.9884 - recall: 0.9858
# Epoch 52: val_loss improved from 0.82113 to 0.62935, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 504ms/step - accuracy: 0.9799 - dice_coef: 0.9799 - iou: 0.9606 - loss: 0.0481 - precision: 0.9883 - recall: 0.9858 - val_accuracy: 0.8541 - val_dice_coef: 0.9107 - val_iou: 0.8360 - val_loss: 0.6294 - val_precision: 0.8667 - val_recall: 0.9641 - learning_rate: 0.0010
# Epoch 53/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9771 - dice_coef: 0.9794 - iou: 0.9597 - loss: 0.0538 - precision: 0.9846 - recall: 0.9859
# Epoch 53: val_loss did not improve from 0.62935
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 0.9772 - dice_coef: 0.9795 - iou: 0.9598 - loss: 0.0535 - precision: 0.9849 - recall: 0.9858 - val_accuracy: 0.8433 - val_dice_coef: 0.9063 - val_iou: 0.8286 - val_loss: 0.7493 - val_precision: 0.8498 - val_recall: 0.9744 - learning_rate: 0.0010
# Epoch 54/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9817 - dice_coef: 0.9810 - iou: 0.9628 - loss: 0.0446 - precision: 0.9895 - recall: 0.9870
# Epoch 54: val_loss improved from 0.62935 to 0.60603, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 560ms/step - accuracy: 0.9815 - dice_coef: 0.9809 - iou: 0.9625 - loss: 0.0449 - precision: 0.9894 - recall: 0.9868 - val_accuracy: 0.8585 - val_dice_coef: 0.9128 - val_iou: 0.8397 - val_loss: 0.6060 - val_precision: 0.8705 - val_recall: 0.9650 - learning_rate: 0.0010
# Epoch 55/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9811 - dice_coef: 0.9814 - iou: 0.9635 - loss: 0.0453 - precision: 0.9874 - recall: 0.9884
# Epoch 55: val_loss did not improve from 0.60603
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.9811 - dice_coef: 0.9813 - iou: 0.9633 - loss: 0.0455 - precision: 0.9873 - recall: 0.9884 - val_accuracy: 0.8608 - val_dice_coef: 0.9139 - val_iou: 0.8415 - val_loss: 0.6118 - val_precision: 0.8760 - val_recall: 0.9603 - learning_rate: 0.0010
# Epoch 56/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9819 - dice_coef: 0.9823 - iou: 0.9653 - loss: 0.0437 - precision: 0.9913 - recall: 0.9856
# Epoch 56: val_loss did not improve from 0.60603
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.9816 - dice_coef: 0.9821 - iou: 0.9648 - loss: 0.0443 - precision: 0.9909 - recall: 0.9856 - val_accuracy: 0.8570 - val_dice_coef: 0.9125 - val_iou: 0.8390 - val_loss: 0.6566 - val_precision: 0.8692 - val_recall: 0.9647 - learning_rate: 0.0010
# Epoch 57/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9827 - dice_coef: 0.9826 - iou: 0.9658 - loss: 0.0418 - precision: 0.9904 - recall: 0.9874
# Epoch 57: val_loss improved from 0.60603 to 0.56967, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 0.9825 - dice_coef: 0.9824 - iou: 0.9655 - loss: 0.0422 - precision: 0.9902 - recall: 0.9874 - val_accuracy: 0.8686 - val_dice_coef: 0.9180 - val_iou: 0.8484 - val_loss: 0.5697 - val_precision: 0.8853 - val_recall: 0.9583 - learning_rate: 0.0010
# Epoch 58/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9795 - dice_coef: 0.9817 - iou: 0.9640 - loss: 0.0481 - precision: 0.9882 - recall: 0.9854
# Epoch 58: val_loss did not improve from 0.56967
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step - accuracy: 0.9796 - dice_coef: 0.9818 - iou: 0.9643 - loss: 0.0479 - precision: 0.9882 - recall: 0.9856 - val_accuracy: 0.8554 - val_dice_coef: 0.9126 - val_iou: 0.8393 - val_loss: 0.7052 - val_precision: 0.8618 - val_recall: 0.9737 - learning_rate: 0.0010
# Epoch 59/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9837 - dice_coef: 0.9833 - iou: 0.9672 - loss: 0.0398 - precision: 0.9906 - recall: 0.9885
# Epoch 59: val_loss did not improve from 0.56967
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 0.9835 - dice_coef: 0.9832 - iou: 0.9670 - loss: 0.0400 - precision: 0.9904 - recall: 0.9885 - val_accuracy: 0.8681 - val_dice_coef: 0.9183 - val_iou: 0.8489 - val_loss: 0.5819 - val_precision: 0.8823 - val_recall: 0.9619 - learning_rate: 0.0010
# Epoch 60/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9823 - dice_coef: 0.9828 - iou: 0.9663 - loss: 0.0427 - precision: 0.9899 - recall: 0.9873
# Epoch 60: val_loss did not improve from 0.56967
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - accuracy: 0.9824 - dice_coef: 0.9828 - iou: 0.9663 - loss: 0.0425 - precision: 0.9898 - recall: 0.9876 - val_accuracy: 0.8651 - val_dice_coef: 0.9164 - val_iou: 0.8458 - val_loss: 0.6218 - val_precision: 0.8815 - val_recall: 0.9586 - learning_rate: 0.0010
# Epoch 61/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9819 - dice_coef: 0.9831 - iou: 0.9667 - loss: 0.0425 - precision: 0.9902 - recall: 0.9865
# Epoch 61: val_loss did not improve from 0.56967
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.9819 - dice_coef: 0.9831 - iou: 0.9667 - loss: 0.0424 - precision: 0.9901 - recall: 0.9867 - val_accuracy: 0.8673 - val_dice_coef: 0.9178 - val_iou: 0.8481 - val_loss: 0.5866 - val_precision: 0.8794 - val_recall: 0.9648 - learning_rate: 0.0010
# Epoch 62/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9816 - dice_coef: 0.9831 - iou: 0.9668 - loss: 0.0436 - precision: 0.9872 - recall: 0.9894
# Epoch 62: val_loss improved from 0.56967 to 0.56524, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 0.9816 - dice_coef: 0.9831 - iou: 0.9668 - loss: 0.0437 - precision: 0.9871 - recall: 0.9894 - val_accuracy: 0.8714 - val_dice_coef: 0.9190 - val_iou: 0.8502 - val_loss: 0.5652 - val_precision: 0.8954 - val_recall: 0.9486 - learning_rate: 0.0010
# Epoch 63/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9809 - dice_coef: 0.9825 - iou: 0.9655 - loss: 0.0448 - precision: 0.9902 - recall: 0.9851
# Epoch 63: val_loss did not improve from 0.56524
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.9810 - dice_coef: 0.9825 - iou: 0.9657 - loss: 0.0445 - precision: 0.9903 - recall: 0.9852 - val_accuracy: 0.8681 - val_dice_coef: 0.9188 - val_iou: 0.8497 - val_loss: 0.5878 - val_precision: 0.8763 - val_recall: 0.9705 - learning_rate: 0.0010
# Epoch 64/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9817 - dice_coef: 0.9830 - iou: 0.9666 - loss: 0.0432 - precision: 0.9829 - recall: 0.9938
# Epoch 64: val_loss improved from 0.56524 to 0.55670, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 507ms/step - accuracy: 0.9818 - dice_coef: 0.9831 - iou: 0.9668 - loss: 0.0432 - precision: 0.9832 - recall: 0.9936 - val_accuracy: 0.8790 - val_dice_coef: 0.9233 - val_iou: 0.8575 - val_loss: 0.5567 - val_precision: 0.9027 - val_recall: 0.9497 - learning_rate: 0.0010
# Epoch 65/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9824 - dice_coef: 0.9832 - iou: 0.9669 - loss: 0.0422 - precision: 0.9930 - recall: 0.9843
# Epoch 65: val_loss improved from 0.55670 to 0.52379, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 576ms/step - accuracy: 0.9826 - dice_coef: 0.9833 - iou: 0.9672 - loss: 0.0418 - precision: 0.9929 - recall: 0.9847 - val_accuracy: 0.8778 - val_dice_coef: 0.9226 - val_iou: 0.8563 - val_loss: 0.5238 - val_precision: 0.8967 - val_recall: 0.9560 - learning_rate: 0.0010
# Epoch 66/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9846 - dice_coef: 0.9842 - iou: 0.9689 - loss: 0.0373 - precision: 0.9879 - recall: 0.9922
# Epoch 66: val_loss did not improve from 0.52379
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.9845 - dice_coef: 0.9842 - iou: 0.9689 - loss: 0.0374 - precision: 0.9880 - recall: 0.9921 - val_accuracy: 0.8725 - val_dice_coef: 0.9192 - val_iou: 0.8505 - val_loss: 0.5769 - val_precision: 0.9008 - val_recall: 0.9431 - learning_rate: 0.0010
# Epoch 67/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9834 - dice_coef: 0.9843 - iou: 0.9692 - loss: 0.0403 - precision: 0.9933 - recall: 0.9853
# Epoch 67: val_loss did not improve from 0.52379
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.9834 - dice_coef: 0.9844 - iou: 0.9693 - loss: 0.0402 - precision: 0.9932 - recall: 0.9855 - val_accuracy: 0.8805 - val_dice_coef: 0.9243 - val_iou: 0.8593 - val_loss: 0.5250 - val_precision: 0.9011 - val_recall: 0.9539 - learning_rate: 0.0010
# Epoch 68/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9825 - dice_coef: 0.9837 - iou: 0.9680 - loss: 0.0418 - precision: 0.9863 - recall: 0.9911
# Epoch 68: val_loss did not improve from 0.52379
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.9825 - dice_coef: 0.9839 - iou: 0.9683 - loss: 0.0417 - precision: 0.9865 - recall: 0.9910 - val_accuracy: 0.8803 - val_dice_coef: 0.9241 - val_iou: 0.8590 - val_loss: 0.5471 - val_precision: 0.9037 - val_recall: 0.9502 - learning_rate: 0.0010
# Epoch 69/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9836 - dice_coef: 0.9844 - iou: 0.9692 - loss: 0.0390 - precision: 0.9916 - recall: 0.9872
# Epoch 69: val_loss improved from 0.52379 to 0.51600, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 505ms/step - accuracy: 0.9836 - dice_coef: 0.9845 - iou: 0.9694 - loss: 0.0390 - precision: 0.9916 - recall: 0.9872 - val_accuracy: 0.8837 - val_dice_coef: 0.9262 - val_iou: 0.8625 - val_loss: 0.5160 - val_precision: 0.9051 - val_recall: 0.9532 - learning_rate: 0.0010
# Epoch 70/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9834 - dice_coef: 0.9844 - iou: 0.9692 - loss: 0.0399 - precision: 0.9881 - recall: 0.9905
# Epoch 70: val_loss improved from 0.51600 to 0.51575, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 560ms/step - accuracy: 0.9833 - dice_coef: 0.9844 - iou: 0.9692 - loss: 0.0400 - precision: 0.9882 - recall: 0.9903 - val_accuracy: 0.8822 - val_dice_coef: 0.9245 - val_iou: 0.8597 - val_loss: 0.5158 - val_precision: 0.9112 - val_recall: 0.9433 - learning_rate: 0.0010
# Epoch 71/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9847 - dice_coef: 0.9850 - iou: 0.9704 - loss: 0.0367 - precision: 0.9903 - recall: 0.9900
# Epoch 71: val_loss improved from 0.51575 to 0.51143, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - accuracy: 0.9848 - dice_coef: 0.9851 - iou: 0.9706 - loss: 0.0365 - precision: 0.9904 - recall: 0.9900 - val_accuracy: 0.8845 - val_dice_coef: 0.9265 - val_iou: 0.8630 - val_loss: 0.5114 - val_precision: 0.9074 - val_recall: 0.9514 - learning_rate: 0.0010
# Epoch 72/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.9874 - dice_coef: 0.9867 - iou: 0.9737 - loss: 0.0311 - precision: 0.9912 - recall: 0.9927
# Epoch 72: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 339ms/step - accuracy: 0.9873 - dice_coef: 0.9865 - iou: 0.9733 - loss: 0.0313 - precision: 0.9912 - recall: 0.9925 - val_accuracy: 0.8840 - val_dice_coef: 0.9261 - val_iou: 0.8624 - val_loss: 0.5258 - val_precision: 0.9102 - val_recall: 0.9472 - learning_rate: 0.0010
# Epoch 73/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9879 - dice_coef: 0.9870 - iou: 0.9743 - loss: 0.0305 - precision: 0.9925 - recall: 0.9920
# Epoch 73: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 350ms/step - accuracy: 0.9878 - dice_coef: 0.9869 - iou: 0.9741 - loss: 0.0307 - precision: 0.9923 - recall: 0.9921 - val_accuracy: 0.8825 - val_dice_coef: 0.9252 - val_iou: 0.8608 - val_loss: 0.5449 - val_precision: 0.9100 - val_recall: 0.9452 - learning_rate: 0.0010
# Epoch 74/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9847 - dice_coef: 0.9859 - iou: 0.9721 - loss: 0.0365 - precision: 0.9917 - recall: 0.9887
# Epoch 74: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 353ms/step - accuracy: 0.9850 - dice_coef: 0.9860 - iou: 0.9723 - loss: 0.0359 - precision: 0.9918 - recall: 0.9890 - val_accuracy: 0.8869 - val_dice_coef: 0.9281 - val_iou: 0.8658 - val_loss: 0.5256 - val_precision: 0.9112 - val_recall: 0.9500 - learning_rate: 0.0010
# Epoch 75/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9883 - dice_coef: 0.9874 - iou: 0.9751 - loss: 0.0293 - precision: 0.9923 - recall: 0.9924
# Epoch 75: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 0.9882 - dice_coef: 0.9875 - iou: 0.9752 - loss: 0.0294 - precision: 0.9925 - recall: 0.9923 - val_accuracy: 0.8858 - val_dice_coef: 0.9277 - val_iou: 0.8651 - val_loss: 0.5342 - val_precision: 0.9067 - val_recall: 0.9542 - learning_rate: 0.0010
# Epoch 76/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9884 - dice_coef: 0.9879 - iou: 0.9761 - loss: 0.0284 - precision: 0.9916 - recall: 0.9935
# Epoch 76: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 359ms/step - accuracy: 0.9884 - dice_coef: 0.9879 - iou: 0.9760 - loss: 0.0285 - precision: 0.9916 - recall: 0.9935 - val_accuracy: 0.8883 - val_dice_coef: 0.9281 - val_iou: 0.8659 - val_loss: 0.5166 - val_precision: 0.9212 - val_recall: 0.9394 - learning_rate: 0.0010
# Epoch 77/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9837 - dice_coef: 0.9858 - iou: 0.9720 - loss: 0.0376 - precision: 0.9912 - recall: 0.9878
# Epoch 77: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 0.9837 - dice_coef: 0.9858 - iou: 0.9721 - loss: 0.0376 - precision: 0.9912 - recall: 0.9878 - val_accuracy: 0.8871 - val_dice_coef: 0.9279 - val_iou: 0.8656 - val_loss: 0.5240 - val_precision: 0.9143 - val_recall: 0.9462 - learning_rate: 0.0010
# Epoch 78/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9860 - dice_coef: 0.9870 - iou: 0.9742 - loss: 0.0330 - precision: 0.9904 - recall: 0.9919
# Epoch 78: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 343ms/step - accuracy: 0.9860 - dice_coef: 0.9870 - iou: 0.9742 - loss: 0.0330 - precision: 0.9904 - recall: 0.9918 - val_accuracy: 0.8862 - val_dice_coef: 0.9271 - val_iou: 0.8642 - val_loss: 0.5518 - val_precision: 0.9184 - val_recall: 0.9400 - learning_rate: 0.0010
# Epoch 79/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9865 - dice_coef: 0.9868 - iou: 0.9740 - loss: 0.0328 - precision: 0.9935 - recall: 0.9890
# Epoch 79: val_loss did not improve from 0.51143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 345ms/step - accuracy: 0.9865 - dice_coef: 0.9869 - iou: 0.9741 - loss: 0.0327 - precision: 0.9935 - recall: 0.9892 - val_accuracy: 0.8836 - val_dice_coef: 0.9253 - val_iou: 0.8609 - val_loss: 0.5310 - val_precision: 0.9174 - val_recall: 0.9376 - learning_rate: 0.0010
# Epoch 80/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9868 - dice_coef: 0.9872 - iou: 0.9748 - loss: 0.0319 - precision: 0.9909 - recall: 0.9923
# Epoch 80: val_loss improved from 0.51143 to 0.50036, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 511ms/step - accuracy: 0.9869 - dice_coef: 0.9873 - iou: 0.9749 - loss: 0.0317 - precision: 0.9910 - recall: 0.9922 - val_accuracy: 0.8921 - val_dice_coef: 0.9300 - val_iou: 0.8692 - val_loss: 0.5004 - val_precision: 0.9309 - val_recall: 0.9332 - learning_rate: 0.0010
# Epoch 81/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9891 - dice_coef: 0.9884 - iou: 0.9771 - loss: 0.0275 - precision: 0.9942 - recall: 0.9918
# Epoch 81: val_loss did not improve from 0.50036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.9889 - dice_coef: 0.9883 - iou: 0.9769 - loss: 0.0278 - precision: 0.9941 - recall: 0.9917 - val_accuracy: 0.8896 - val_dice_coef: 0.9286 - val_iou: 0.8667 - val_loss: 0.5113 - val_precision: 0.9268 - val_recall: 0.9346 - learning_rate: 0.0010
# Epoch 82/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9885 - dice_coef: 0.9882 - iou: 0.9766 - loss: 0.0288 - precision: 0.9929 - recall: 0.9922
# Epoch 82: val_loss did not improve from 0.50036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - accuracy: 0.9885 - dice_coef: 0.9882 - iou: 0.9766 - loss: 0.0287 - precision: 0.9930 - recall: 0.9922 - val_accuracy: 0.8928 - val_dice_coef: 0.9309 - val_iou: 0.8707 - val_loss: 0.5190 - val_precision: 0.9274 - val_recall: 0.9381 - learning_rate: 0.0010
# Epoch 83/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9891 - dice_coef: 0.9884 - iou: 0.9770 - loss: 0.0271 - precision: 0.9928 - recall: 0.9931
# Epoch 83: val_loss did not improve from 0.50036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.9892 - dice_coef: 0.9884 - iou: 0.9771 - loss: 0.0270 - precision: 0.9929 - recall: 0.9931 - val_accuracy: 0.8878 - val_dice_coef: 0.9277 - val_iou: 0.8652 - val_loss: 0.5590 - val_precision: 0.9276 - val_recall: 0.9311 - learning_rate: 0.0010
# Epoch 84/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9865 - dice_coef: 0.9874 - iou: 0.9751 - loss: 0.0321 - precision: 0.9906 - recall: 0.9919
# Epoch 84: val_loss did not improve from 0.50036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 353ms/step - accuracy: 0.9866 - dice_coef: 0.9875 - iou: 0.9753 - loss: 0.0318 - precision: 0.9908 - recall: 0.9920 - val_accuracy: 0.8922 - val_dice_coef: 0.9303 - val_iou: 0.8697 - val_loss: 0.5191 - val_precision: 0.9298 - val_recall: 0.9346 - learning_rate: 0.0010
# Epoch 85/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9888 - dice_coef: 0.9885 - iou: 0.9773 - loss: 0.0276 - precision: 0.9940 - recall: 0.9916
# Epoch 85: val_loss did not improve from 0.50036
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 351ms/step - accuracy: 0.9887 - dice_coef: 0.9884 - iou: 0.9770 - loss: 0.0279 - precision: 0.9939 - recall: 0.9915 - val_accuracy: 0.8922 - val_dice_coef: 0.9305 - val_iou: 0.8700 - val_loss: 0.5236 - val_precision: 0.9285 - val_recall: 0.9361 - learning_rate: 0.0010
# Epoch 86/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9882 - dice_coef: 0.9885 - iou: 0.9772 - loss: 0.0288 - precision: 0.9914 - recall: 0.9934
# Epoch 86: val_loss improved from 0.50036 to 0.49808, saving model to Membrance_resunet_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.9882 - dice_coef: 0.9885 - iou: 0.9773 - loss: 0.0288 - precision: 0.9915 - recall: 0.9933 - val_accuracy: 0.8931 - val_dice_coef: 0.9299 - val_iou: 0.8690 - val_loss: 0.4981 - val_precision: 0.9404 - val_recall: 0.9238 - learning_rate: 0.0010
# Epoch 87/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9882 - dice_coef: 0.9881 - iou: 0.9765 - loss: 0.0286 - precision: 0.9931 - recall: 0.9916
# Epoch 87: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 0.9883 - dice_coef: 0.9881 - iou: 0.9765 - loss: 0.0284 - precision: 0.9930 - recall: 0.9919 - val_accuracy: 0.8947 - val_dice_coef: 0.9318 - val_iou: 0.8723 - val_loss: 0.5272 - val_precision: 0.9346 - val_recall: 0.9324 - learning_rate: 0.0010
# Epoch 88/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9897 - dice_coef: 0.9891 - iou: 0.9785 - loss: 0.0255 - precision: 0.9946 - recall: 0.9922
# Epoch 88: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - accuracy: 0.9897 - dice_coef: 0.9890 - iou: 0.9782 - loss: 0.0256 - precision: 0.9946 - recall: 0.9921 - val_accuracy: 0.8918 - val_dice_coef: 0.9303 - val_iou: 0.8698 - val_loss: 0.5447 - val_precision: 0.9278 - val_recall: 0.9364 - learning_rate: 0.0010
# Epoch 89/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9909 - dice_coef: 0.9895 - iou: 0.9793 - loss: 0.0236 - precision: 0.9945 - recall: 0.9937
# Epoch 89: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 0.9907 - dice_coef: 0.9893 - iou: 0.9789 - loss: 0.0239 - precision: 0.9945 - recall: 0.9936 - val_accuracy: 0.8936 - val_dice_coef: 0.9313 - val_iou: 0.8715 - val_loss: 0.5478 - val_precision: 0.9333 - val_recall: 0.9324 - learning_rate: 0.0010
# Epoch 90/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9848 - dice_coef: 0.9867 - iou: 0.9738 - loss: 0.0369 - precision: 0.9898 - recall: 0.9906
# Epoch 90: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 349ms/step - accuracy: 0.9850 - dice_coef: 0.9869 - iou: 0.9740 - loss: 0.0365 - precision: 0.9900 - recall: 0.9906 - val_accuracy: 0.8892 - val_dice_coef: 0.9291 - val_iou: 0.8675 - val_loss: 0.5437 - val_precision: 0.9190 - val_recall: 0.9433 - learning_rate: 0.0010
# Epoch 91/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9832 - dice_coef: 0.9852 - iou: 0.9708 - loss: 0.0423 - precision: 0.9893 - recall: 0.9889
# Epoch 91: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 0.9836 - dice_coef: 0.9854 - iou: 0.9713 - loss: 0.0414 - precision: 0.9896 - recall: 0.9891 - val_accuracy: 0.8940 - val_dice_coef: 0.9327 - val_iou: 0.8738 - val_loss: 0.5721 - val_precision: 0.9206 - val_recall: 0.9481 - learning_rate: 0.0010
# Epoch 92/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9875 - dice_coef: 0.9878 - iou: 0.9760 - loss: 0.0305 - precision: 0.9912 - recall: 0.9927
# Epoch 92: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.9875 - dice_coef: 0.9878 - iou: 0.9759 - loss: 0.0305 - precision: 0.9914 - recall: 0.9925 - val_accuracy: 0.8923 - val_dice_coef: 0.9310 - val_iou: 0.8709 - val_loss: 0.5469 - val_precision: 0.9248 - val_recall: 0.9406 - learning_rate: 0.0010
# Epoch 93/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9885 - dice_coef: 0.9885 - iou: 0.9772 - loss: 0.0282 - precision: 0.9917 - recall: 0.9937
# Epoch 93: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 392ms/step - accuracy: 0.9886 - dice_coef: 0.9885 - iou: 0.9773 - loss: 0.0281 - precision: 0.9916 - recall: 0.9938 - val_accuracy: 0.8954 - val_dice_coef: 0.9327 - val_iou: 0.8739 - val_loss: 0.5560 - val_precision: 0.9314 - val_recall: 0.9370 - learning_rate: 0.0010
# Epoch 94/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9909 - dice_coef: 0.9897 - iou: 0.9795 - loss: 0.0238 - precision: 0.9968 - recall: 0.9914
# Epoch 94: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.9908 - dice_coef: 0.9897 - iou: 0.9796 - loss: 0.0239 - precision: 0.9967 - recall: 0.9915 - val_accuracy: 0.8919 - val_dice_coef: 0.9310 - val_iou: 0.8709 - val_loss: 0.5625 - val_precision: 0.9224 - val_recall: 0.9430 - learning_rate: 0.0010
# Epoch 95/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.9900 - dice_coef: 0.9895 - iou: 0.9793 - loss: 0.0250 - precision: 0.9919 - recall: 0.9952
# Epoch 95: val_loss did not improve from 0.49808
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 343ms/step - accuracy: 0.9900 - dice_coef: 0.9896 - iou: 0.9795 - loss: 0.0249 - precision: 0.9922 - recall: 0.9950 - val_accuracy: 0.8942 - val_dice_coef: 0.9319 - val_iou: 0.8725 - val_loss: 0.5651 - val_precision: 0.9330 - val_recall: 0.9336 - learning_rate: 0.0010
# Epoch 96/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9896 - dice_coef: 0.9898 - iou: 0.9799 - loss: 0.0255 - precision: 0.9938 - recall: 0.9929
# Epoch 96: val_loss did not improve from 0.49808
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 0.9897 - dice_coef: 0.9899 - iou: 0.9800 - loss: 0.0254 - precision: 0.9936 - recall: 0.9932 - val_accuracy: 0.8917 - val_dice_coef: 0.9297 - val_iou: 0.8687 - val_loss: 0.5628 - val_precision: 0.9371 - val_recall: 0.9254 - learning_rate: 0.0010
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.8865 - dice_coef: 0.9229 - iou: 0.8568 - loss: 0.5301 - precision: 0.9232 - recall: 0.9289

# %%
tf.keras.utils.plot_model(
    model,
    show_shapes=False,
    show_dtype=False,
    show_layer_names=True,
    rankdir='TB',
    expand_nested=False,
    dpi=300,
    layer_range=None
)

# %%
def plot_training_history(history, figsize=(8, 4)):
    """
    Plot training and validation metrics/loss over epochs based on available metrics in history.

    Overfitting:
     It happens when a model learns training data too well, including noise and specific patterns, leading to poor
     performance on unseen data. It often occurs when training metrics improve significantly while validation
     metrics plateau or worsen, showing the model memorizes rather than generalizes.
    - Signs of Overfitting:
      - Training metrics improve, but validation metrics plateau or decline.
      - A large gap between training and validation performance.
      - Strong performance on training data but poor results on test data.
    - Causes:
      - Complex Model: Too many parameters (e.g., deep U-Net) with a small dataset.
      - Small Dataset: Limited data leads to memorization instead of generalization.
      - Lack of Regularization: Missing techniques like dropout, weight decay, or data augmentation.

    Underfitting:
      It happens when a model fails to learn the training data, leading to poor performance on both training
      and validation/test sets. This can occur if the model is too simple or insufficiently trained to capture the
      data’s complexity.
    - Signs of Underfitting:
        - Low training and validation metrics that don’t improve significantly.
        - Training metrics improve slowly or plateau at suboptimal values.
        - Poor performance on the training set itself.
    - Causes:
        - Simple Model: Insufficient capacity (e.g., too few layers or filters).
        - Insufficient Training: Too few epochs or a high learning rate.
        - Small/Imbalanced Dataset: Lack of diversity limits generalizable learning.

    Precision:
    - It measures the proportion of predicted positive instances (foreground pixels in your case) that are actually correct.
    - High precision means the model is good at avoiding false positives—when it predicts a pixel as foreground, it’s usually correct.
    - Low precision indicates the model is predicting too many false positives (e.g., predicting background pixels as foreground).
    - True Positives (TP): Pixels correctly predicted as foreground (1).
    - False Positives (FP): Pixels incorrectly predicted as foreground (predicted 1, but actually 0).

    Recall (also called sensitivity):
    - It measures the proportion of actual positive instances (foreground pixels) that the model correctly identifies.
    - High recall means the model is good at detecting most of the foreground pixels, minimizing false negatives.
    - Low recall indicates the model is missing many foreground pixels (e.g., predicting them as background).
    - False Negatives (FN): Pixels that are actually foreground (1) but predicted as background (0).

    Args:
    - history: History object from model.fit()
    """
    # Get metrics with both training and validation versions
    metrics_to_plot = [m for m in history.history if not m.startswith('val_') and f'val_{m}' in history.history]

    # If no metrics found, raise an error
    if not metrics_to_plot: raise ValueError("No valid metrics found in history to plot.")

    # Define epochs range
    epochs = range(1, len(history.history['loss']) + 1)

    # Create subplots dynamically based on number of metrics
    n_metrics = len(metrics_to_plot)
    n_rows = (n_metrics + 1) // 2  # Ceiling division to determine rows
    n_cols = min(n_metrics, 2)     # Max 2 columns

    plt.figure(figsize=figsize)  # Adjust height based on number of rows

    for i, metric in enumerate(metrics_to_plot, 1):
        plt.subplot(n_rows, n_cols, i)
        plt.plot(epochs, history.history[metric], label=f'Training {metric}')
        plt.plot(epochs, history.history[f'val_{metric}'], label=f'Validation {metric}')
        plt.ylabel(metric.capitalize(), fontsize=10)
        if i == 1: plt.legend(fontsize=9)
        if i == n_metrics - 1 or i == n_metrics: plt.xlabel('Epoch', fontsize=10)
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# Plot the history
plot_training_history(history, figsize=(8, 4))

# %%
def plot_evaluation_results(results, figsize=(4, 4)):
    """
    Plot test set evaluation results as a bar chart based on available metrics in results.

    Args:
    - results: Dictionary from model.evaluate(return_dict=True)
    """
    # Extract all metrics from the results dictionary
    metrics_to_plot = list(results.keys())

    # If no metrics found, raise an error
    if not metrics_to_plot: raise ValueError("No metrics found in results to plot.")

    # Create bar plot with dynamic width and assigned colors
    plt.figure(figsize=figsize)

    # Get corresponding values
    values = [results[metric] for metric in metrics_to_plot]

    # Define a color map and assign colors to each bar
    colors = plt.cm.summer(np.linspace(0, 1, len(metrics_to_plot)))
    bars = plt.bar(metrics_to_plot, values, color=colors)

    # Add value labels on top of bars
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'{yval:.3f}',
                 ha='center', va='bottom' if yval < 0.5 else 'top', color='black', rotation=0)

    plt.margins(x=0.1)
    plt.ylabel('Value', fontsize=10)
    plt.xticks(rotation=15, ha='right')
    plt.ylim(0, max(1.0, max(values) * 1.1))  # Adjust y-axis for visibility
    plt.xlabel('Metrics', fontsize=10, labelpad=5)
    plt.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.title('Test Set Evaluation Metrics', fontsize=10)
    plt.tight_layout()
    plt.show()

# Plot the results
plot_evaluation_results(results, figsize=(4, 4))

# %% [markdown]
# <font color=#5b0d8f size="4.5" face="Arial"><b>8️⃣ Test the model</b></font>

# %%
def evaluate_segmentation_predictions(test_dataset, predictions, num_sample=3):
    """
    Evaluate model predictions by calculating IoU and Dice coefficient for a batch of test images.

    Args:
    - test_dataset: Dataset containing test images and masks.
    - predictions: Model predictions (binary masks).

    Returns:
    - None: Prints IoU and Dice scores for each sample in the batch.

    IoU:
    - Computes Intersection over Union (IoU/Jaccard index) between masks. IoU measures the overlap between two samples
    with values ranging from 0 (no overlap) to 1 (perfect overlap). Defined as:
    IoU = |X ∩ Y| / |X ∪ Y|
    - Args:
        - y_true: Ground truth masks (tensor)
        - y_pred: Predicted masks (tensor)
    - Returns:
      - Tensor: Scalar IoU value

    Dice coefficient:
    - Computes the Dice coefficient (F1 score) between ground truth and predicted masks. The Dice coefficient measures
    the overlap between two samples, with values ranging from 0 (no overlap) to 1 (perfect overlap). Defined as:
    Dice = (2 * |X ∩ Y|) / (|X| + |Y|)
    - Args:
       - y_true: Ground truth masks (tensor)
       - y_pred: Predicted probability masks (tensor)
    - Returns:
       - Tensor: Scalar Dice coefficient value
    """
    # Convert predictions to binary (threshold at 0.5 for binary segmentation)
    predictions = (predictions > 0.5).astype(np.uint8)

    # Extract a small batch of data from test_dataset for visualization
    for batch in test_dataset.take(1):
        test_images, test_masks = batch
        break

    # Convert to numpy arrays for easier manipulation
    test_images = test_images.numpy()
    test_masks = test_masks.numpy()

    def iou(y_true, y_pred):
        # Ensure tensors are float32 for consistent computation
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Compute intersection
        intersection = tf.reduce_sum(y_true * y_pred)
        # Compute total area covered by both masks
        total = tf.reduce_sum(y_true + y_pred)
        # Compute union (total area minus intersection)
        union = total - intersection
        # Calculate IoU with smoothing factor
        return (intersection + 1e-4) / (union + 1e-4)

    def dice_coef(y_true, y_pred):
        # Ensure tensors are float32 for consistent computation
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # Compute intersection (element-wise multiplication followed by sum)
        intersection = tf.reduce_sum(y_true * y_pred)
        # Compute union (sum of individual masks)
        union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
        # Calculate Dice coefficient with smoothing factor
        return (2. * intersection + 1e-4) / (union + 1e-4)

    # Calculate IoU and Dice for each sample in the batch
    for i in range(num_sample):
        iou_score = iou(test_masks[i], predictions[i])
        acc = accuracy_score(test_masks[i].flatten(), predictions[i].flatten())
        dice_score = dice_coef(test_masks[i], predictions[i])
        rec = recall_score(test_masks[i].flatten(), predictions[i].flatten(), labels=[0, 1], average="binary")
        pre = precision_score(test_masks[i].flatten(), predictions[i].flatten(), labels=[0, 1], average="binary")

        print(f"Sample {i+1} Accuracy: {acc:.3f}; IoU: {iou_score:.3f}; Dice coef: {dice_score:.3f}; Recall: {rec:.3f}; Precision: {pre:.3f}")

# %%
predictions = model.predict(test_dataset, verbose=0)
evaluate_segmentation_predictions(test_dataset=test_dataset, predictions=predictions, num_sample=2)
# Out:
# Sample 1 Accuracy: 0.890; IoU: 0.869; Dice coef: 0.930; Recall: 0.954; Precision: 0.907
# Sample 2 Accuracy: 0.892; IoU: 0.867; Dice coef: 0.929; Recall: 0.937; Precision: 0.920

# %%
def display_predictions(test_images, test_masks, predictions, indx=0, figsize=(6, 4)):
    plt.figure(figsize=figsize)

    # Original Image
    plt.subplot(131)
    plt.imshow(test_images[indx], cmap='gray')
    plt.title(f"Test Image {indx + 1}", fontsize=10)
    plt.axis('off')

    # Ground Truth Mask
    plt.subplot(132)
    plt.imshow(test_masks[indx], cmap='gray')
    plt.title(f"Ground Truth Mask {indx + 1}", fontsize=10)
    plt.axis('off')

    # Predicted Mask
    plt.subplot(133)
    plt.imshow(predictions[indx], cmap='gray')
    plt.title(f"Predicted Mask {indx + 1}", fontsize=10)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# Extract a small batch of data from test_dataset for visualization
for batch in test_dataset.take(1):
    test_images, test_masks = batch
    break

# Convert to numpy arrays for easier manipulation
test_images = test_images.numpy()
test_masks = test_masks.numpy()

display_predictions(test_images, test_masks, predictions, indx=0, figsize=(6, 4))

# %% [markdown]
# <font color=#ff4578 size="4.5" face="Arial"><b>9️⃣ Load previously trained Model</b></font>

# %%
model = load_model('Membrance_resunet_model.keras')
